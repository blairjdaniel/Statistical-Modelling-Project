# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import pandas as pd
import os # use this to access your environment variables
import requests # this will be used to call the APIs
from IPython.display import JSON #for nice JSON (or dict) display in JupyterLab (not currently supported in Jupyter Notebook)
from pprint import pprint # you will most likely use this instead of the JSON printing function

# %%
# get network data
city_bike_networks = requests.get("http://api.citybik.es/v2/networks").json()

# view json in nice format
city_bike_networks
# Out:
# {'networks': [{'id': 'abu-dhabi-careem-bike',
#    'name': 'Abu Dhabi Careem BIKE',
#    'location': {'latitude': 24.4866,
#     'longitude': 54.3728,
#     'city': 'Abu Dhabi',
#     'country': 'AE'},
#    'href': '/v2/networks/abu-dhabi-careem-bike',
#    'company': ['Careem'],
#    'gbfs_href': 'https://dubai.publicbikesystem.net/customer/gbfs/v2/en/gbfs.json'},
#   {'id': 'acces-velo-saguenay',
#    'name': 'Accès Vélo',
#    'location': {'latitude': 48.433333,
#     'longitude': -71.083333,
#     'city': 'Saguenay',
#     'country': 'CA'},
#    'href': '/v2/networks/acces-velo-saguenay',
#    'company': ['PBSC Urban Solutions'],
#    'gbfs_href': 'https://saguenay.publicbikesystem.net/customer/gbfs/v2/gbfs.json'},
#   {'id': 'aksu',
#    'name': 'Aksu',
#    'location': {'latitude': 41.1664,
#     'longitude': 80.2617,
#     'city': '阿克苏市 (Aksu City)',
#     'country': 'CN'},
#    'href': '/v2/networks/aksu',
#    'company': ['阿克苏公共服务']},
#   {'id': 'alba',
#    'name': 'Alba',
#    'location': {'latitude': 44.716667,
#     'longitude': 8.083333,
#     'city': 'Alba',
#     'country': 'IT'},
#    'href': '/v2/networks/alba',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=139'},
#   {'id': 'albabici',
#    'name': 'AlbaBici',
#    'location': {'latitude': 38.9943,
#     'longitude': -1.8602,
#     'city': 'Albacete',
#     'country': 'ES'},
#    'href': '/v2/networks/albabici',
#    'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#    'system': 'bicicard'},
#   {'id': 'algira',
#    'name': 'AlGira',
#    'location': {'latitude': 39.2082,
#     'longitude': -8.6252,
#     'city': 'Almeirim',
#     'country': 'PT'},
#    'href': '/v2/networks/algira',
#    'company': ['Município de Almeirim', 'Wegoshare, Lda'],
#    'ebikes': True},
#   {'id': 'almatybike',
#    'name': 'Almatybike',
#    'location': {'latitude': 43.239101,
#     'longitude': 76.9268076,
#     'city': 'Almaty',
#     'country': 'KZ'},
#    'href': '/v2/networks/almatybike',
#    'company': ['Velobike.kz, LLP', 'Smoove'],
#    'system': 'Velobike'},
#   {'id': 'alsa-nextbike-leon',
#    'name': 'Alsa nextbike León',
#    'location': {'latitude': 42.5987263,
#     'longitude': -5.5670959,
#     'city': 'León',
#     'country': 'ES'},
#    'href': '/v2/networks/alsa-nextbike-leon',
#    'company': ['Leonbici Nextbike Gmbh Y Autobuses Urbanos De Leon S.a. Ute'],
#    'system': 'Nextbike'},
#   {'id': 'ambici-badalona',
#    'name': 'Ambici',
#    'location': {'latitude': 41.447,
#     'longitude': 2.245,
#     'city': 'Badalona',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-badalona',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-castelldefels',
#    'name': 'Ambici',
#    'location': {'latitude': 41.2816,
#     'longitude': 1.97678,
#     'city': 'Castelldefels',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-castelldefels',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-cornella-de-llobregat',
#    'name': 'Ambici',
#    'location': {'latitude': 41.3585,
#     'longitude': 2.07081,
#     'city': 'Cornellà de Llobregat',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-cornella-de-llobregat',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-el-prat-de-llobregat',
#    'name': 'Ambici',
#    'location': {'latitude': 41.3239,
#     'longitude': 2.09317,
#     'city': 'El Prat de Llobregat',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-el-prat-de-llobregat',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-esplugues-de-llobregat',
#    'name': 'Ambici',
#    'location': {'latitude': 41.3771,
#     'longitude': 2.08938,
#     'city': 'Esplugues de Llobregat',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-esplugues-de-llobregat',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-gava',
#    'name': 'Ambici',
#    'location': {'latitude': 41.303,
#     'longitude': 2.00269,
#     'city': 'Gavà',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-gava',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-molins-de-rei',
#    'name': 'Ambici',
#    'location': {'latitude': 41.4132,
#     'longitude': 2.02037,
#     'city': 'Molins de Rei',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-molins-de-rei',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-sant-boi-de-llobregat',
#    'name': 'Ambici',
#    'location': {'latitude': 41.3458,
#     'longitude': 2.03404,
#     'city': 'Sant Boi de Llobregat',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-sant-boi-de-llobregat',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-sant-joan-despi',
#    'name': 'Ambici',
#    'location': {'latitude': 41.368,
#     'longitude': 2.05635,
#     'city': 'Sant Joan Despí',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-sant-joan-despi',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-sant-just-desvern',
#    'name': 'Ambici',
#    'location': {'latitude': 41.3807,
#     'longitude': 2.07496,
#     'city': 'Sant Just Desvern',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-sant-just-desvern',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-santa-coloma-de-gramenet',
#    'name': 'Ambici',
#    'location': {'latitude': 41.4459,
#     'longitude': 2.21033,
#     'city': 'Santa Coloma de Gramenet',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-santa-coloma-de-gramenet',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'ambici-viladecans',
#    'name': 'Ambici',
#    'location': {'latitude': 41.3165,
#     'longitude': 2.01306,
#     'city': 'Viladecans',
#     'country': 'ES'},
#    'href': '/v2/networks/ambici-viladecans',
#    'company': ['Nextbike GmbH',
#     'TIER Mobility SE',
#     'Transports Metropolitans de Barcelona',
#     'Projectes i Serveis de Mobilitat S.A'],
#    'system': 'Ambici'},
#   {'id': 'andria',
#    'name': 'Andria in Bici',
#    'location': {'latitude': 41.224346932834,
#     'longitude': 16.296983922753956,
#     'city': 'Andria',
#     'country': 'IT'},
#    'href': '/v2/networks/andria',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=192'},
#   {'id': 'aral',
#    'name': 'Aral',
#    'location': {'latitude': 40.5577,
#     'longitude': 81.2879,
#     'city': '阿拉尔市 (Aral)',
#     'country': 'CN'},
#    'href': '/v2/networks/aral',
#    'company': ['阿克苏公共服务']},
#   {'id': 'arbike',
#    'name': 'ARbike',
#    'location': {'latitude': 43.473333,
#     'longitude': 11.87,
#     'city': 'Arezzo',
#     'country': 'IT'},
#    'href': '/v2/networks/arbike',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=84'},
#   {'id': 'arriva-nitra',
#    'name': 'Arriva',
#    'location': {'latitude': 48.3088,
#     'longitude': 18.0783,
#     'city': 'Nitra',
#     'country': 'SK'},
#    'href': '/v2/networks/arriva-nitra',
#    'company': ['Nextbike GmbH']},
#   {'id': 'arval-scandicci',
#    'name': 'ARVAL',
#    'location': {'latitude': 43.7701,
#     'longitude': 11.1592,
#     'city': 'Scandicci',
#     'country': 'IT'},
#    'href': '/v2/networks/arval-scandicci',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'ascoli-piceno',
#    'name': 'Ascoli Piceno',
#    'location': {'latitude': 42.85,
#     'longitude': 13.583333,
#     'city': 'Ascoli Piceno',
#     'country': 'IT'},
#    'href': '/v2/networks/ascoli-piceno',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=73'},
#   {'id': 'athens-bikes',
#    'name': 'AthensBikes',
#    'location': {'latitude': 37.9838,
#     'longitude': 23.7275,
#     'city': 'Athens',
#     'country': 'GR'},
#    'href': '/v2/networks/athens-bikes',
#    'company': ['Brainbox Technology', 'Smoove SAS'],
#    'system': 'EasyBike'},
#   {'id': 'austin',
#    'name': 'ATX MetroBike',
#    'location': {'latitude': 30.26408,
#     'longitude': -97.74355,
#     'city': 'Austin, TX',
#     'country': 'US'},
#    'href': '/v2/networks/austin',
#    'company': ['BCycle, LLC'],
#    'system': 'BCycle',
#    'gbfs_href': 'https://gbfs.bcycle.com/bcycle_austin/gbfs.json'},
#   {'id': 'auxrmlevelo',
#    'name': 'AuxR_M le vélo',
#    'location': {'latitude': 47.797221,
#     'longitude': 3.572376,
#     'city': 'Auxerre',
#     'country': 'FR'},
#    'href': '/v2/networks/auxrmlevelo',
#    'company': ['Fifteen SAS'],
#    'system': 'Fifteen'},
#   {'id': 'avelo-quebec',
#    'name': 'àVélo',
#    'location': {'latitude': 46.81305,
#     'longitude': -71.2168,
#     'city': 'Québec',
#     'country': 'CA'},
#    'href': '/v2/networks/avelo-quebec',
#    'company': ['PBSC Urban Solutions'],
#    'gbfs_href': 'https://quebec.publicbikesystem.net/customer/gbfs/v2/gbfs.json'},
#   {'id': 'aventura',
#    'name': 'Aventura BCycle',
#    'location': {'latitude': 25.95711,
#     'longitude': -80.1395,
#     'city': 'Aventura, FL',
#     'country': 'US'},
#    'href': '/v2/networks/aventura',
#    'company': ['BCycle, LLC'],
#    'system': 'BCycle',
#    'gbfs_href': 'https://gbfs.bcycle.com/bcycle_aventura/gbfs.json'},
#   {'id': 'aviles-en-bici',
#    'name': 'Avilés en Bici',
#    'location': {'latitude': 43.5554,
#     'longitude': -5.9222,
#     'city': 'Avilés',
#     'country': 'ES'},
#    'href': '/v2/networks/aviles-en-bici',
#    'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#    'system': 'bicicard'},
#   {'id': 'aw-bike',
#    'name': 'AW-bike Ahrweiler',
#    'location': {'latitude': 50.5452,
#     'longitude': 7.1212,
#     'city': 'Ahrweiler',
#     'country': 'DE'},
#    'href': '/v2/networks/aw-bike',
#    'company': ['nextbike GmbH'],
#    'gbfs_href': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rh/gbfs.json'},
#   {'id': 'baksi-antalya',
#    'name': 'Baksi',
#    'location': {'latitude': 36.862048,
#     'longitude': 30.638866,
#     'city': 'Antalya',
#     'country': 'TR'},
#    'href': '/v2/networks/baksi-antalya',
#    'company': ['Baksi Bike Sharing System'],
#    'system': 'Baksi'},
#   {'id': 'baksi-cabis',
#    'name': 'Çabis',
#    'location': {'latitude': 40.1531,
#     'longitude': 26.4146,
#     'city': 'Çanakkale',
#     'country': 'TR'},
#    'href': '/v2/networks/baksi-cabis',
#    'company': ['Baksi Bike Sharing System'],
#    'system': 'Baksi'},
#   {'id': 'baksi-nilesplit',
#    'name': 'Nilesplit',
#    'location': {'latitude': 40.2127,
#     'longitude': 28.9627,
#     'city': 'Nilüfer',
#     'country': 'TR'},
#    'href': '/v2/networks/baksi-nilesplit',
#    'company': ['Baksi Bike Sharing System'],
#    'system': 'Baksi'},
#   {'id': 'batumvelo',
#    'name': 'Batumvelo',
#    'location': {'latitude': 41.660906,
#     'longitude': 41.678835,
#     'city': 'Batumi',
#     'country': 'GE'},
#    'href': '/v2/networks/batumvelo',
#    'company': ['Smoove'],
#    'system': 'Smoove'},
#   {'id': 'bay-wheels',
#    'name': 'Bay Wheels',
#    'location': {'latitude': 37.7141454,
#     'longitude': -122.25,
#     'city': 'San Francisco Bay Area, CA',
#     'country': 'US'},
#    'href': '/v2/networks/bay-wheels',
#    'company': ['Motivate LLC'],
#    'gbfs_href': 'https://gbfs.baywheels.com/gbfs/gbfs.json'},
#   {'id': 'bealler',
#    'name': 'Pedaleando por Aller (BeALLER)',
#    'location': {'latitude': 43.1482,
#     'longitude': -5.6295,
#     'city': 'Aller',
#     'country': 'ES'},
#    'href': '/v2/networks/bealler',
#    'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#    'system': 'bicicard'},
#   {'id': 'belfastbikes-belfast',
#    'name': 'BelfastBikes',
#    'location': {'latitude': 54.5969,
#     'longitude': -5.92918,
#     'city': 'Belfast',
#     'country': 'GB'},
#    'href': '/v2/networks/belfastbikes-belfast',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'bentonville',
#    'name': 'Bentonville BCycle',
#    'location': {'latitude': 36.3605,
#     'longitude': -94.1996,
#     'city': 'Bentonville, AR',
#     'country': 'US'},
#    'href': '/v2/networks/bentonville',
#    'company': ['BCycle, LLC'],
#    'system': 'BCycle',
#    'gbfs_href': 'https://gbfs.bcycle.com/bcycle_bentonville/gbfs.json'},
#   {'id': 'bergen-bysykkel',
#    'name': 'Bysykkel',
#    'location': {'latitude': 60.391263,
#     'longitude': 5.322054,
#     'city': 'Bergen',
#     'country': 'NO'},
#    'href': '/v2/networks/bergen-bysykkel',
#    'company': ['Urban Sharing AS'],
#    'gbfs_href': 'https://gbfs.urbansharing.com/bergenbysykkel.no/gbfs.json'},
#   {'id': 'bergisches-e-bike',
#    'name': 'Bergisches e-Bike',
#    'location': {'latitude': 51.0192,
#     'longitude': 7.18025,
#     'city': 'Bergisches e-Bike',
#     'country': 'DE'},
#    'href': '/v2/networks/bergisches-e-bike',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'beryl-bcp',
#    'name': 'Beryl - Bournemouth, Christchurch and Poole',
#    'location': {'latitude': 50.7196,
#     'longitude': -1.8734,
#     'city': 'Bournemouth, Christchurch and Poole',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-bcp',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/BCP/gbfs.json'},
#   {'id': 'beryl-brighton',
#    'name': 'Beryl - Brighton',
#    'location': {'latitude': 50.8222,
#     'longitude': -0.1403,
#     'city': 'Brighton',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-brighton',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Brighton/gbfs.json'},
#   {'id': 'beryl-cornwall',
#    'name': 'Beryl - Cornwall',
#    'location': {'latitude': 50.2616,
#     'longitude': -5.051,
#     'city': 'Cornwall',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-cornwall',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Cornwall/gbfs.json'},
#   {'id': 'beryl-dorchester-weymouth-portland',
#    'name': 'Beryl - Dorchester, Weymouth and Portland',
#    'location': {'latitude': 50.6085,
#     'longitude': -2.454,
#     'city': 'Dorchester, Weymouth and Portland',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-dorchester-weymouth-portland',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Weymouth/gbfs.json'},
#   {'id': 'beryl-eastleigh',
#    'name': 'Beryl - Eastleigh',
#    'location': {'latitude': 50.9691,
#     'longitude': -1.3603,
#     'city': 'Eastleigh',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-eastleigh',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Eastleigh/gbfs.json'},
#   {'id': 'beryl-greater-manchester',
#    'name': 'Beryl - Greater Manchester',
#    'location': {'latitude': 53.4795,
#     'longitude': -2.2436,
#     'city': 'Greater Manchester',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-greater-manchester',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Greater_Manchester/gbfs.json'},
#   {'id': 'beryl-guildford',
#    'name': 'Beryl - Guildford',
#    'location': {'latitude': 51.2397,
#     'longitude': -0.5764,
#     'city': 'Guildford',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-guildford',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Guildford/gbfs.json'},
#   {'id': 'beryl-hereford',
#    'name': 'Beryl - Hereford',
#    'location': {'latitude': 52.0549,
#     'longitude': -2.7156,
#     'city': 'Hereford',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-hereford',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Hereford/gbfs.json'},
#   {'id': 'beryl-hertsmere',
#    'name': 'Beryl - Hertsmere',
#    'location': {'latitude': 51.6577,
#     'longitude': -0.2695,
#     'city': 'Hertsmere',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-hertsmere',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Hertsmere/gbfs.json'},
#   {'id': 'beryl-leeds',
#    'name': 'Beryl - Leeds',
#    'location': {'latitude': 53.7971,
#     'longitude': -1.5438,
#     'city': 'Leeds',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-leeds',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Leeds/gbfs.json'},
#   {'id': 'beryl-norwich',
#    'name': 'Beryl - Norwich',
#    'location': {'latitude': 52.6288,
#     'longitude': 1.2934,
#     'city': 'Norwich',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-norwich',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Norwich/gbfs.json'},
#   {'id': 'beryl-plymouth',
#    'name': 'Beryl - Plymouth',
#    'location': {'latitude': 50.3714,
#     'longitude': -4.1421,
#     'city': 'Plymouth',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-plymouth',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Plymouth/gbfs.json'},
#   {'id': 'beryl-stevenage',
#    'name': 'Beryl - Stevenage',
#    'location': {'latitude': 51.9059,
#     'longitude': -0.1905,
#     'city': 'Stevenage',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-stevenage',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Stevenage/gbfs.json'},
#   {'id': 'beryl-watford',
#    'name': 'Beryl - Watford',
#    'location': {'latitude': 51.6556,
#     'longitude': -0.3953,
#     'city': 'Watford',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-watford',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Watford/gbfs.json'},
#   {'id': 'beryl-west-midlands',
#    'name': 'Beryl - West Midlands',
#    'location': {'latitude': 52.4798,
#     'longitude': -1.9014,
#     'city': 'West Midlands',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-west-midlands',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/West_Midlands/gbfs.json'},
#   {'id': 'beryl-worcester',
#    'name': 'Beryl - Worcester',
#    'location': {'latitude': 52.1912,
#     'longitude': -2.2206,
#     'city': 'Worcester',
#     'country': 'GB'},
#    'href': '/v2/networks/beryl-worcester',
#    'company': ['Beryl'],
#    'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Worcester/gbfs.json'},
#   {'id': 'bia',
#    'name': 'BIA',
#    'location': {'latitude': 40.8599,
#     'longitude': -8.6246,
#     'city': 'Ovar',
#     'country': 'PT'},
#    'href': '/v2/networks/bia',
#    'company': ['Município de Ovar',
#     'Share2Go - Mobilidade Partilhada, Sociedade Unipessoal Lda'],
#    'ebikes': True},
#   {'id': 'bianzone-in-bici',
#    'name': 'Bianzone in Bici',
#    'location': {'latitude': 46.188197,
#     'longitude': 10.109354,
#     'city': 'Bianzone',
#     'country': 'IT'},
#    'href': '/v2/networks/bianzone-in-bici',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=147'},
#   {'id': 'biba',
#    'name': 'BiBa',
#    'location': {'latitude': 38.878,
#     'longitude': -6.9701,
#     'city': 'Badajoz',
#     'country': 'ES'},
#    'href': '/v2/networks/biba',
#    'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#    'system': 'bicicard'},
#   {'id': 'bibo',
#    'name': 'BIBO',
#    'location': {'latitude': 40.4125,
#     'longitude': -3.8909,
#     'city': 'Boadilla del Monte',
#     'country': 'ES'},
#    'href': '/v2/networks/bibo',
#    'company': ['Movilidad Urbana Sostenible SLU']},
#   {'id': 'bici-bolzano',
#    'name': 'Bici Bolzano',
#    'location': {'latitude': 46.49,
#     'longitude': 11.3401,
#     'city': 'Bolzano',
#     'country': 'IT'},
#    'href': '/v2/networks/bici-bolzano',
#    'company': ['Ecospazio Logiss S.r.l.']},
#   {'id': 'bici-co',
#    'name': 'BICI&CO',
#    'location': {'latitude': 45.8080597,
#     'longitude': 9.0851765,
#     'city': 'Como',
#     'country': 'IT'},
#    'href': '/v2/networks/bici-co',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=157'},
#   {'id': 'bici-ferrol-terra',
#    'name': 'BiciFerrolTerra',
#    'location': {'latitude': 43.4896,
#     'longitude': -8.2193,
#     'city': 'Ferrol - Narón',
#     'country': 'ES'},
#    'href': '/v2/networks/bici-ferrol-terra',
#    'company': ['2K SYSTEMS, S.L.', 'Bike Works Naron']},
#   {'id': 'bici-in-busto',
#    'name': 'Bici in Busto',
#    'location': {'latitude': 45.610555,
#     'longitude': 8.852062,
#     'city': 'Busto Arsizio',
#     'country': 'IT'},
#    'href': '/v2/networks/bici-in-busto',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=66'},
#   {'id': 'bici-perugia',
#    'name': 'Bici Perugia',
#    'location': {'latitude': 43.1107168,
#     'longitude': 12.3908279,
#     'city': 'Perugia',
#     'country': 'IT'},
#    'href': '/v2/networks/bici-perugia',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=122'},
#   {'id': 'bicialcazar',
#    'name': 'BiciAlcázar',
#    'location': {'latitude': 39.3901,
#     'longitude': -3.2101,
#     'city': 'Alcázar de San Juan',
#     'country': 'ES'},
#    'href': '/v2/networks/bicialcazar',
#    'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#    'system': 'bicicard'},
#   {'id': 'biciarousa',
#    'name': 'BiciArousa',
#    'location': {'latitude': 42.5521,
#     'longitude': -8.8666,
#     'city': 'A Illa de Arousa',
#     'country': 'ES'},
#    'href': '/v2/networks/biciarousa',
#    'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#    'system': 'bicicard'},
#   {'id': 'biciarteixo',
#    'name': 'biciArteixo',
#    'location': {'latitude': 43.3053,
#     'longitude': -8.5069,
#     'city': 'Arteixo',
#     'country': 'ES'},
#    'href': '/v2/networks/biciarteixo',
#    'company': ['Servizos Urbanos Municipais de Arteixo, S. A.'],
#    'system': 'Nextbike'},
#   {'id': 'bicibur',
#    'name': 'BiciBur',
#    'location': {'latitude': 42.34392,
#     'longitude': -3.69697,
#     'city': 'Burgos',
#     'country': 'ES'},
#    'href': '/v2/networks/bicibur',
#    'company': ['Instituto Tecnológico de Castilla y León (ITCL)']},
#   {'id': 'bicicas',
#    'name': 'Bicicas',
#    'location': {'latitude': 39.9856,
#     'longitude': -0.0389,
#     'city': 'Castelló de la Plana',
#     'country': 'ES'},
#    'href': '/v2/networks/bicicas',
#    'company': ['Maquiver S.L.U.', 'Ajuntament de Castelló de la Plana']},
#   {'id': 'bicicletar',
#    'name': 'Bicicletar',
#    'location': {'latitude': -3.7321944,
#     'longitude': -38.510347,
#     'city': 'Fortaleza',
#     'country': 'BR'},
#    'href': '/v2/networks/bicicletar',
#    'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#    'system': 'Samba'},
#   {'id': 'bicicorunha',
#    'name': 'Bicicoruña',
#    'location': {'latitude': 43.3623,
#     'longitude': -8.4115,
#     'city': 'A Coruña',
#     'country': 'ES'},
#    'href': '/v2/networks/bicicorunha',
#    'company': ['PBSC Urban Solutions'],
#    'gbfs_href': 'https://acoruna.publicbikesystem.net/customer/gbfs/v2/gbfs.json'},
#   {'id': 'bicicuenca',
#    'name': 'Bici Pública Cuenca',
#    'location': {'latitude': -2.897,
#     'longitude': -79.0038,
#     'city': 'Cuenca',
#     'country': 'EC'},
#    'href': '/v2/networks/bicicuenca',
#    'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#    'system': 'Samba'},
#   {'id': 'bicielx',
#    'name': 'Bicielx',
#    'location': {'latitude': 38.2665,
#     'longitude': -0.7,
#     'city': 'Elx',
#     'country': 'ES'},
#    'href': '/v2/networks/bicielx',
#    'company': ['Promociones e Iniciativas Municipales de Elche, S.A.']},
#   {'id': 'bicikelj',
#    'name': 'Bicikelj',
#    'location': {'latitude': 46.05645089999999,
#     'longitude': 14.5080702,
#     'city': 'Ljubljana',
#     'country': 'SI'},
#    'href': '/v2/networks/bicikelj',
#    'company': ['JCDecaux'],
#    'system': 'Cyclocity',
#    'license': {'name': 'Open Licence',
#     'url': 'https://developer.jcdecaux.com/#/opendata/licence'},
#    'source': 'https://developer.jcdecaux.com'},
#   {'id': 'bicilog',
#    'name': 'BiciLog',
#    'location': {'latitude': 42.4658,
#     'longitude': -2.4402,
#     'city': 'Logroño',
#     'country': 'ES'},
#    'href': '/v2/networks/bicilog',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'bicimad',
#    'name': 'BiciMAD',
#    'location': {'latitude': 40.4168,
#     'longitude': -3.7038,
#     'city': 'Madrid',
#     'country': 'ES'},
#    'href': '/v2/networks/bicimad',
#    'company': ['Empresa Municipal de Transportes de Madrid, S.A.'],
#    'system': 'bicimad',
#    'source': 'https://mobilitylabs.emtmadrid.es/'},
#   {'id': 'bicimia',
#    'name': 'bicimia',
#    'location': {'latitude': 45.5378,
#     'longitude': 10.2173,
#     'city': 'Brescia',
#     'country': 'IT'},
#    'href': '/v2/networks/bicimia',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://bicimia.bresciamobilita.it/frmLeStazioni.aspx?ID=40'},
#   {'id': 'bicimislata',
#    'name': 'BiciMislata',
#    'location': {'latitude': 39.4763,
#     'longitude': -0.4182,
#     'city': 'Mislata',
#     'country': 'ES'},
#    'href': '/v2/networks/bicimislata',
#    'company': ['Movilidad Urbana Sostenible, S.L'],
#    'system': 'Nextbike'},
#   {'id': 'bicincitta-acquarica-del-capo',
#    'name': 'Bicincittà',
#    'location': {'latitude': 39.9144573,
#     'longitude': 18.2450324,
#     'city': 'Acquarica del Capo',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-acquarica-del-capo',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=146'},
#   {'id': 'bicincitta-acquaviva-delle-fonti',
#    'name': 'Bicincittà',
#    'location': {'latitude': 40.9303721,
#     'longitude': 16.8414374,
#     'city': 'Acquaviva delle fonti',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-acquaviva-delle-fonti',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=160'},
#   {'id': 'bicincitta-alghero',
#    'name': 'Bicincittà',
#    'location': {'latitude': 40.5579517,
#     'longitude': 8.319294900000001,
#     'city': 'Alghero',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-alghero',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=237'},
#   {'id': 'bicincitta-assemini',
#    'name': 'Bicincittà',
#    'location': {'latitude': 39.28956306007679,
#     'longitude': 9.006601555294765,
#     'city': 'Assemini',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-assemini',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=205'},
#   {'id': 'bicincitta-borgarello',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.23963753440171,
#     'longitude': 9.136150475640875,
#     'city': 'Borgarello',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-borgarello',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=208'},
#   {'id': 'bicincitta-brancaleone',
#    'name': 'Bicincittà',
#    'location': {'latitude': 37.9679084,
#     'longitude': 16.0757749,
#     'city': 'Brancaleone',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-brancaleone',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=104'},
#   {'id': 'bicincitta-carrara',
#    'name': 'Bicincittà',
#    'location': {'latitude': 44.07731805550891,
#     'longitude': 10.097172450401331,
#     'city': 'Carrara',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-carrara',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=211'},
#   {'id': 'bicincitta-casaletto-spartano',
#    'name': 'Bicincittà',
#    'location': {'latitude': 40.1532801,
#     'longitude': 15.6211479,
#     'city': 'Casaletto Spartano',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-casaletto-spartano',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=199'},
#   {'id': 'bicincitta-castel-guelfo-the-style-outlets',
#    'name': 'Bicincittà',
#    'location': {'latitude': 44.4328527,
#     'longitude': 11.6750857,
#     'city': 'Castel Guelfo di Bologna',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-castel-guelfo-the-style-outlets',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=233'},
#   {'id': 'bicincitta-cesena',
#    'name': 'Mi Muovo in bici',
#    'location': {'latitude': 44.1396438,
#     'longitude': 12.2464292,
#     'city': 'Cesena',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-cesena',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=120'},
#   {'id': 'bicincitta-cisterna-di-latina',
#    'name': 'Bicincittà',
#    'location': {'latitude': 41.5754029,
#     'longitude': 12.8284772,
#     'city': 'Cisterna di Latina',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-cisterna-di-latina',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=217'},
#   {'id': 'bicincitta-costa-blu',
#    'name': 'Costa Blu',
#    'location': {'latitude': 42.5009,
#     'longitude': 14.1282,
#     'city': 'Montesilvano',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-costa-blu',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=268'},
#   {'id': 'bicincitta-elmas',
#    'name': 'Bicincittà',
#    'location': {'latitude': 39.2634329,
#     'longitude': 9.0515805,
#     'city': 'Elmas',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-elmas',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=218'},
#   {'id': 'bicincitta-ente-parco-del-circeo',
#    'name': 'Bicincittà',
#    'location': {'latitude': 41.3151015,
#     'longitude': 13.0330782,
#     'city': 'Parco Nazionale del Circeo',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-ente-parco-del-circeo',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=135'},
#   {'id': 'bicincitta-ente-parco-di-montemarcello-magra',
#    'name': 'Bicincittà',
#    'location': {'latitude': 44.1143897,
#     'longitude': 9.9635986,
#     'city': 'Ente Parco Montemarcello Magra',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-ente-parco-di-montemarcello-magra',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=132'},
#   {'id': 'bicincitta-ente-parco-san-rossore',
#    'name': 'Bicincittà',
#    'location': {'latitude': 43.723826,
#     'longitude': 10.339509,
#     'city': 'Parco naturale Migliarino San Rossore Massaciuccoli',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-ente-parco-san-rossore',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=145'},
#   {'id': 'bicincitta-forli',
#    'name': 'Mi Muovo in Bici',
#    'location': {'latitude': 44.2227398,
#     'longitude': 12.0407312,
#     'city': 'Forlì',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-forli',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=119'},
#   {'id': 'bicincitta-gaeta',
#    'name': 'Bicincittà',
#    'location': {'latitude': 41.209620965538036,
#     'longitude': 13.584335125656139,
#     'city': 'Gaeta',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-gaeta',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=207'},
#   {'id': 'bicincitta-gallipoli',
#    'name': 'Bicincittà',
#    'location': {'latitude': 40.0558554,
#     'longitude': 17.9925085,
#     'city': 'Gallipoli',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-gallipoli',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=109'},
#   {'id': 'bicincitta-imola',
#    'name': 'Mi Muovo in bici',
#    'location': {'latitude': 44.3559128,
#     'longitude': 11.7161197,
#     'city': 'Imola',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-imola',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=196'},
#   {'id': 'bicincitta-lavis',
#    'name': 'Bicincittà',
#    'location': {'latitude': 46.1408423,
#     'longitude': 11.1124935,
#     'city': 'Lavis',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-lavis',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=238'},
#   {'id': 'bicincitta-livorno',
#    'name': 'Bicincittà',
#    'location': {'latitude': 43.548473,
#     'longitude': 10.3105674,
#     'city': 'Livorno',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-livorno',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=226'},
#   {'id': 'bicincitta-mantova',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.15866370764634,
#     'longitude': 10.783718973016335,
#     'city': 'Mantova',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-mantova',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=204'},
#   {'id': 'bicincitta-massa',
#    'name': 'Bici in Massa',
#    'location': {'latitude': 44.0146,
#     'longitude': 10.1017,
#     'city': 'Massa',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-massa',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=275'},
#   {'id': 'bicincitta-mezzocorona',
#    'name': 'Bicincittà',
#    'location': {'latitude': 46.2339047,
#     'longitude': 11.1277461,
#     'city': 'Mezzocorona',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-mezzocorona',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=229'},
#   {'id': 'bicincitta-mezzolombardo',
#    'name': 'Bicincittà',
#    'location': {'latitude': 46.21400260000001,
#     'longitude': 11.0967867,
#     'city': 'Mezzolombardo',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-mezzolombardo',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=228'},
#   {'id': 'bicincitta-modena',
#    'name': 'Mi Muovo in bici',
#    'location': {'latitude': 44.647128,
#     'longitude': 10.9252269,
#     'city': 'Modena',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-modena',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=180'},
#   {'id': 'bicincitta-monserrato',
#    'name': 'Bicincittà',
#    'location': {'latitude': 39.2560191,
#     'longitude': 9.1453579,
#     'city': 'Monserrato',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-monserrato',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=220'},
#   {'id': 'bicincitta-montecatini-terme',
#    'name': 'Bicincittà',
#    'location': {'latitude': 43.88362791665083,
#     'longitude': 10.764385656591799,
#     'city': 'Montecatini Terme',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-montecatini-terme',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=210'},
#   {'id': 'bicincitta-monteriggioni',
#    'name': 'Sipedala',
#    'location': {'latitude': 43.3896,
#     'longitude': 11.2236,
#     'city': 'Monteriggioni',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-monteriggioni',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=274'},
#   {'id': 'bicincitta-monza',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.5845001,
#     'longitude': 9.2744485,
#     'city': 'Monza',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-monza',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=224'},
#   {'id': 'bicincitta-morigerati',
#    'name': 'Bicincittà',
#    'location': {'latitude': 40.1422031,
#     'longitude': 15.5298525,
#     'city': 'Morigerati',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-morigerati',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=200'},
#   {'id': 'bicincitta-parco-dei-colli-di-bergamo',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.72295637032245,
#     'longitude': 9.649230073016383,
#     'city': 'Parco dei Colli di Bergamo',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-parco-dei-colli-di-bergamo',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=203'},
#   {'id': 'bicincitta-parco-molentargius-saline',
#    'name': 'Bicincittà',
#    'location': {'latitude': 39.2052545,
#     'longitude': 9.146761099999999,
#     'city': 'Parco Naturale Molentargius - Saline',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-parco-molentargius-saline',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=151'},
#   {'id': 'bicincitta-pista',
#    'name': 'PisTA!',
#    'location': {'latitude': 40.4351,
#     'longitude': 17.2096,
#     'city': 'Taranto',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-pista',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=270'},
#   {'id': 'bicincitta-pizzighettone-formigara',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.186748819167434,
#     'longitude': 9.778087948479424,
#     'city': 'Pizzighettone e Formigara',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-pizzighettone-formigara',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=209'},
#   {'id': 'bicincitta-porto-torres',
#    'name': 'Bicincittà',
#    'location': {'latitude': 40.8333682,
#     'longitude': 8.402292899999999,
#     'city': 'Porto Torres',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-porto-torres',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=221'},
#   {'id': 'bicincitta-rivarolo-canavese',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.306633,
#     'longitude': 7.723242,
#     'city': 'Rivarolo Canavese',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-rivarolo-canavese',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=227'},
#   {'id': 'bicincitta-san-donato-milanese',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.4092402,
#     'longitude': 9.2684867,
#     'city': 'San Donato Milanese',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-san-donato-milanese',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=234'},
#   {'id': 'bicincitta-san-giovanni-in-persiceto',
#    'name': 'Mi Muovo in Bici',
#    'location': {'latitude': 44.6405433,
#     'longitude': 11.1893053,
#     'city': 'San Giovanni in Persiceto',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-san-giovanni-in-persiceto',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=101'},
#   {'id': 'bicincitta-san-lazzaro-di-savena',
#    'name': 'Mi Muovo in Bici',
#    'location': {'latitude': 44.4702725,
#     'longitude': 11.409399,
#     'city': 'San Lazzaro di Savena',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-san-lazzaro-di-savena',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=100'},
#   {'id': 'bicincitta-san-michele-alladige',
#    'name': 'Bicincittà',
#    'location': {'latitude': 46.1878653,
#     'longitude': 11.1330423,
#     'city': "San Michele All'adige",
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-san-michele-alladige',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=231'},
#   {'id': 'bicincitta-san-teodoro',
#    'name': 'Bicincittà',
#    'location': {'latitude': 40.7722837,
#     'longitude': 9.6695458,
#     'city': 'San Teodoro',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-san-teodoro',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=225'},
#   {'id': 'bicincitta-scafati',
#    'name': 'Bicincittà',
#    'location': {'latitude': 40.7620174,
#     'longitude': 14.5363969,
#     'city': 'Scafati',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-scafati',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=106'},
#   {'id': 'bicincitta-scandiano',
#    'name': 'Mi Muovo in Bici',
#    'location': {'latitude': 44.5982342,
#     'longitude': 10.6909273,
#     'city': 'Scandiano',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-scandiano',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=94'},
#   {'id': 'bicincitta-selargius',
#    'name': 'Bicincittà',
#    'location': {'latitude': 39.2596768,
#     'longitude': 9.1629372,
#     'city': 'Selargius',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-selargius',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=219'},
#   {'id': 'bicincitta-siena',
#    'name': 'Bicincittà',
#    'location': {'latitude': 43.3186,
#     'longitude': 11.3306,
#     'city': 'Siena',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-siena',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=202'},
#   {'id': 'bicincitta-tivat',
#    'name': 'Bicincittà',
#    'location': {'latitude': 42.4349809,
#     'longitude': 18.7066398,
#     'city': 'TV',
#     'country': 'ME'},
#    'href': '/v2/networks/bicincitta-tivat',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=87'},
#   {'id': 'bicincitta-tortoli',
#    'name': 'Bicincittà',
#    'location': {'latitude': 39.92664489852196,
#     'longitude': 9.654953570777934,
#     'city': 'Tortolì',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-tortoli',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=206'},
#   {'id': 'bicincitta-treviglio',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.5293372,
#     'longitude': 9.591435899999999,
#     'city': 'Treviglio',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-treviglio',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=174'},
#   {'id': 'bicincitta-trieste',
#    'name': 'BiTS',
#    'location': {'latitude': 45.6495,
#     'longitude': 13.7768,
#     'city': 'Trieste',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-trieste',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=266'},
#   {'id': 'bicincitta-vicolungo-the-style-outlets',
#    'name': 'Bicincittà',
#    'location': {'latitude': 45.47167229999999,
#     'longitude': 8.4633922,
#     'city': 'Vicolungo',
#     'country': 'IT'},
#    'href': '/v2/networks/bicincitta-vicolungo-the-style-outlets',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=232'},
#   {'id': 'bicing',
#    'name': 'Bicing',
#    'location': {'latitude': 41.3850639,
#     'longitude': 2.1734035,
#     'city': 'Barcelona',
#     'country': 'ES'},
#    'href': '/v2/networks/bicing',
#    'company': ['Barcelona de Serveis Municipals, S.A. (BSM)', 'CESPA', 'PBSC'],
#    'ebikes': True},
#   {'id': 'bicinquartucciu',
#    'name': 'BicinQuartucciu',
#    'location': {'latitude': 39.25043149806156,
#     'longitude': 9.179296426489255,
#     'city': 'Quartucciu',
#     'country': 'IT'},
#    'href': '/v2/networks/bicinquartucciu',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=193'},
#   {'id': 'bicinrivas',
#    'name': 'BiciNRivas',
#    'location': {'latitude': 40.35353,
#     'longitude': -3.53095,
#     'city': 'Rivas-Vaciamadrid',
#     'country': 'ES'},
#    'href': '/v2/networks/bicinrivas',
#    'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#    'system': 'bicicard'},
#   {'id': 'bicipalma',
#    'name': 'Bicipalma',
#    'location': {'latitude': 39.57119,
#     'longitude': 2.646634,
#     'city': 'Palma',
#     'country': 'ES'},
#    'href': '/v2/networks/bicipalma',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'bicisanvi',
#    'name': 'Bicisanvi',
#    'location': {'latitude': 38.39611,
#     'longitude': -0.5236,
#     'city': 'Sant Vicent del Raspeig',
#     'country': 'ES'},
#    'href': '/v2/networks/bicisanvi',
#    'company': ['Movilidad Urbana Sostenible SLU']},
#   {'id': 'bicischio',
#    'name': 'BiciSchio',
#    'location': {'latitude': 45.7170517,
#     'longitude': 11.3597702,
#     'city': 'Schio',
#     'country': 'IT'},
#    'href': '/v2/networks/bicischio',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=91'},
#   {'id': 'biclis',
#    'name': 'biclis',
#    'location': {'latitude': 39.7495,
#     'longitude': -8.8074,
#     'city': 'Leiria',
#     'country': 'PT'},
#    'href': '/v2/networks/biclis',
#    'company': ['Município de Leiria',
#     'Share2Go - Mobilidade Partilhada, Sociedade Unipessoal Lda'],
#    'ebikes': True},
#   {'id': 'bicloo',
#    'name': 'Bicloo',
#    'location': {'latitude': 47.218371,
#     'longitude': -1.553621,
#     'city': 'Nantes',
#     'country': 'FR'},
#    'href': '/v2/networks/bicloo',
#    'company': ['JCDecaux'],
#    'system': 'Cyclocity',
#    'license': {'name': 'Open Licence',
#     'url': 'https://developer.jcdecaux.com/#/opendata/licence'},
#    'source': 'https://developer.jcdecaux.com'},
#   {'id': 'bicyklezadobreskutky',
#    'name': 'Bicykle za dobré skutky',
#    'location': {'latitude': 48.996275,
#     'longitude': 21.234341,
#     'city': 'Prešov',
#     'country': 'SK'},
#    'href': '/v2/networks/bicyklezadobreskutky',
#    'company': ['Open Source Bike Share'],
#    'system': 'OpenSourceBikeShare'},
#   {'id': 'biella',
#    'name': 'Biella',
#    'location': {'latitude': 45.5775,
#     'longitude': 8.051111,
#     'city': 'Biella',
#     'country': 'IT'},
#    'href': '/v2/networks/biella',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=112'},
#   {'id': 'bigi',
# ...
#    'system': 'Nextbike'},
#   {'id': 'vitelinhas',
#    'name': 'Vitelinhas',
#    'location': {'latitude': 41.4513,
#     'longitude': -8.1728,
#     'city': 'Fafe',
#     'country': 'PT'},
#    'href': '/v2/networks/vitelinhas',
#    'company': ['Município de Fafe',
#     'Share2Go - Mobilidade Partilhada, Sociedade Unipessoal Lda'],
#    'ebikes': True},
#   {'id': 'vlille',
#    'name': "V'Lille",
#    'location': {'latitude': 50.62925,
#     'longitude': 3.057256,
#     'city': 'Lille',
#     'country': 'FR'},
#    'href': '/v2/networks/vlille',
#    'company': ['Keolis'],
#    'system': 'Keolis',
#    'source': 'https://data.lillemetropole.fr/catalogue/dataset/c8166e8f-36a2-40ca-af1a-a00ab1fb20f7'},
#   {'id': 'vrn-bensheim',
#    'name': 'VRN',
#    'location': {'latitude': 49.6803,
#     'longitude': 8.6189,
#     'city': 'Bensheim',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-bensheim',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-burstadt',
#    'name': 'VRN',
#    'location': {'latitude': 49.6461,
#     'longitude': 8.44917,
#     'city': 'Bürstadt',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-burstadt',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-eppelheim',
#    'name': 'VRN',
#    'location': {'latitude': 49.4025,
#     'longitude': 8.6331,
#     'city': 'Eppelheim',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-eppelheim',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-heidelberg',
#    'name': 'VRN',
#    'location': {'latitude': 49.4023,
#     'longitude': 8.67577,
#     'city': 'Heidelberg',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-heidelberg',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-heppenheim',
#    'name': 'VRN',
#    'location': {'latitude': 49.6431,
#     'longitude': 8.63889,
#     'city': 'Heppenheim',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-heppenheim',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-hockenheim',
#    'name': 'VRN',
#    'location': {'latitude': 49.3227,
#     'longitude': 8.54258,
#     'city': 'Hockenheim',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-hockenheim',
#    'company': ['Nextbike GmbH']},
#   {'id': 'vrn-kaiserslautern',
#    'name': 'VRN',
#    'location': {'latitude': 49.4413,
#     'longitude': 7.75566,
#     'city': 'Kaiserslautern',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-kaiserslautern',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-landau',
#    'name': 'VRN',
#    'location': {'latitude': 49.1975,
#     'longitude': 8.11693,
#     'city': 'Landau in der Pfalz',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-landau',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-ludwigshafen',
#    'name': 'VRN',
#    'location': {'latitude': 49.4741,
#     'longitude': 8.43287,
#     'city': 'Ludwigshafen',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-ludwigshafen',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-mannheim',
#    'name': 'VRN',
#    'location': {'latitude': 49.4869,
#     'longitude': 8.45638,
#     'city': 'Mannheim',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-mannheim',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-schwetzingen',
#    'name': 'VRN',
#    'location': {'latitude': 49.3863,
#     'longitude': 8.5756,
#     'city': 'Schwetzingen',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-schwetzingen',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-speyer',
#    'name': 'VRN',
#    'location': {'latitude': 49.3126,
#     'longitude': 8.45295,
#     'city': 'Speyer',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-speyer',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-weinheim',
#    'name': 'VRN',
#    'location': {'latitude': 49.545,
#     'longitude': 8.66027,
#     'city': 'Weinheim',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-weinheim',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vrn-worms',
#    'name': 'VRN',
#    'location': {'latitude': 49.6394,
#     'longitude': 8.34618,
#     'city': 'Worms',
#     'country': 'DE'},
#    'href': '/v2/networks/vrn-worms',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vvtregiorad-ellmau',
#    'name': 'VVT REGIORAD Tirol',
#    'location': {'latitude': 47.5134,
#     'longitude': 12.3025,
#     'city': 'Ellmau',
#     'country': 'AT'},
#    'href': '/v2/networks/vvtregiorad-ellmau',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'vvtregiorad-kufstein',
#    'name': 'VVT REGIORAD Tirol',
#    'location': {'latitude': 47.583,
#     'longitude': 12.1692,
#     'city': 'Kufstein',
#     'country': 'AT'},
#    'href': '/v2/networks/vvtregiorad-kufstein',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'waterford',
#    'name': 'TFI Bikes',
#    'location': {'latitude': 52.2475049,
#     'longitude': -7.1130299,
#     'city': 'Waterford',
#     'country': 'IE'},
#    'href': '/v2/networks/waterford',
#    'company': ['The National Transport Authority'],
#    'system': 'TFI Bikes'},
#   {'id': 'we-cycle',
#    'name': 'WE-cycle',
#    'location': {'latitude': 39.194951,
#     'longitude': -106.837002,
#     'city': 'Aspen, CO',
#     'country': 'US'},
#    'href': '/v2/networks/we-cycle',
#    'company': ['PBSC', 'Alta Bicycle Share, Inc'],
#    'gbfs_href': 'https://asp.publicbikesystem.net/ube/gbfs/v1/gbfs.json'},
#   {'id': 'we-love-bike',
#    'name': 'We Love bike',
#    'location': {'latitude': 45.3097228,
#     'longitude': 9.503715999999999,
#     'city': 'Lodi',
#     'country': 'IT'},
#    'href': '/v2/networks/we-love-bike',
#    'company': ['Comunicare S.r.l.'],
#    'system': 'Bicincittà',
#    'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=190'},
#   {'id': 'westbike-erkelenz',
#    'name': 'westBike',
#    'location': {'latitude': 51.0753,
#     'longitude': 6.31233,
#     'city': 'Erkelenz',
#     'country': 'DE'},
#    'href': '/v2/networks/westbike-erkelenz',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'westbike-geilenkirchen',
#    'name': 'westBike',
#    'location': {'latitude': 50.9671,
#     'longitude': 6.11886,
#     'city': 'Geilenkirchen',
#     'country': 'DE'},
#    'href': '/v2/networks/westbike-geilenkirchen',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'westbike-heinsberg',
#    'name': 'westBike',
#    'location': {'latitude': 51.0597,
#     'longitude': 6.11849,
#     'city': 'Heinsberg',
#     'country': 'DE'},
#    'href': '/v2/networks/westbike-heinsberg',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'westbike-hueckelhoven',
#    'name': 'westBike',
#    'location': {'latitude': 51.0529,
#     'longitude': 6.21933,
#     'city': 'Hückelhoven',
#     'country': 'DE'},
#    'href': '/v2/networks/westbike-hueckelhoven',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'westbike-wegberg',
#    'name': 'westBike',
#    'location': {'latitude': 51.1427,
#     'longitude': 6.2813,
#     'city': 'Wegberg',
#     'country': 'DE'},
#    'href': '/v2/networks/westbike-wegberg',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'westcargo-bath',
#    'name': 'WESTcargo Bath',
#    'location': {'latitude': 51.3814,
#     'longitude': -2.35519,
#     'city': 'Bath',
#     'country': 'GB'},
#    'href': '/v2/networks/westcargo-bath',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'westcargo-bristol',
#    'name': 'WESTcargo Bristol',
#    'location': {'latitude': 51.4587,
#     'longitude': -2.57355,
#     'city': 'Bristol',
#     'country': 'GB'},
#    'href': '/v2/networks/westcargo-bristol',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'whitebikes',
#    'name': 'WhiteBikes',
#    'location': {'latitude': 48.149424,
#     'longitude': 17.113922,
#     'city': 'Bratislava',
#     'country': 'SK'},
#    'href': '/v2/networks/whitebikes',
#    'company': ['Open Source Bike Share'],
#    'system': 'OpenSourceBikeShare'},
#   {'id': 'wienmobil-rad',
#    'name': 'WienMobil Rad',
#    'location': {'latitude': 48.2081743,
#     'longitude': 16.3738189,
#     'city': 'Wien',
#     'country': 'AT'},
#    'href': '/v2/networks/wienmobil-rad',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'winsenrad',
#    'name': 'WinsenRad',
#    'location': {'latitude': 53.3547,
#     'longitude': 10.2067,
#     'city': 'Winsen (Luhe)',
#     'country': 'DE'},
#    'href': '/v2/networks/winsenrad',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'wk-bike-bremen-bremen',
#    'name': 'WK-Bike',
#    'location': {'latitude': 53.0781,
#     'longitude': 8.80132,
#     'city': 'Bremen',
#     'country': 'DE'},
#    'href': '/v2/networks/wk-bike-bremen-bremen',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'wolf-ride-bike-share',
#    'name': 'Wolf Ride Bike Share (Stony Brook University)',
#    'location': {'latitude': 40.9124,
#     'longitude': -73.1249,
#     'city': 'Stony Brook',
#     'country': 'US'},
#    'href': '/v2/networks/wolf-ride-bike-share',
#    'company': ['Stony Brook University'],
#    'gbfs_href': 'https://sbu.publicbikesystem.net/customer/gbfs/v2/gbfs.json'},
#   {'id': 'wrm-wroclaw',
#    'name': 'WRM',
#    'location': {'latitude': 51.1097,
#     'longitude': 17.0485,
#     'city': 'Wrocław',
#     'country': 'PL'},
#    'href': '/v2/networks/wrm-wroclaw',
#    'company': ['Nextbike GmbH']},
#   {'id': 'wupsi',
#    'name': 'wupsiRad Leverkusen',
#    'location': {'latitude': 51.0732,
#     'longitude': 7.00814,
#     'city': 'Leverkusen',
#     'country': 'DE'},
#    'href': '/v2/networks/wupsi',
#    'company': ['Nextbike GmbH'],
#    'system': 'Nextbike'},
#   {'id': 'xian-public-bicycle',
#    'name': "Xi'an Public Bicycle",
#    'location': {'latitude': 34.2688,
#     'longitude': 108.9458,
#     'city': "西安 (Xi'an)",
#     'country': 'CN'},
#    'href': '/v2/networks/xian-public-bicycle',
#    'company': ['西安城市公共自行车服务管理有']},
#   {'id': 'yelo-velo',
#    'name': 'Yélo Vélo',
#    'location': {'latitude': 46.1591,
#     'longitude': -1.1509,
#     'city': 'La Rochelle',
#     'country': 'FR'},
#    'href': '/v2/networks/yelo-velo',
#    'company': ["Communauté d'Agglomération de La Rochelle"],
#    'license': {'name': 'Licence Ouverte',
#     'url': 'https://www.etalab.gouv.fr/licence-ouverte-open-licence/'}},
#   {'id': 'youbike-chiayi-city',
#    'name': 'YouBike',
#    'location': {'latitude': 23.4797,
#     'longitude': 120.4397,
#     'city': '台灣 Chiayi City',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-chiayi-city',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-hsinchu-city',
#    'name': 'YouBike',
#    'location': {'latitude': 24.8018,
#     'longitude': 120.9714,
#     'city': '新竹市 Hsinchu City',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-hsinchu-city',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-hsinchu-county',
#    'name': 'YouBike',
#    'location': {'latitude': 24.8269,
#     'longitude': 121.0129,
#     'city': '新竹縣 Hsinchu County',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-hsinchu-county',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-hsinchu-science-park',
#    'name': 'YouBike',
#    'location': {'latitude': 24.7818,
#     'longitude': 121.005,
#     'city': '新竹科學工業園區 Hsinchu Science Park',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-hsinchu-science-park',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-kaohsiung-city',
#    'name': 'YouBike',
#    'location': {'latitude': 22.6314,
#     'longitude': 120.3018,
#     'city': '高雄市 Kaohsiung City',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-kaohsiung-city',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-miaoli-county',
#    'name': 'YouBike',
#    'location': {'latitude': 24.5648,
#     'longitude': 120.8185,
#     'city': '台灣 Miaoli County',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-miaoli-county',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-new-taipei',
#    'name': 'YouBike',
#    'location': {'latitude': 25.0169826,
#     'longitude': 121.4627868,
#     'city': '新北市 New Taipei',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-new-taipei',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-pingtung-county',
#    'name': 'YouBike',
#    'location': {'latitude': 22.683,
#     'longitude': 120.4879,
#     'city': '屏東縣 Pingtung County',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-pingtung-county',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-putian-city',
#    'name': 'YouBike',
#    'location': {'latitude': 25.4504,
#     'longitude': 119.0126,
#     'city': '莆田市 (Putian City)',
#     'country': 'CN'},
#    'href': '/v2/networks/youbike-putian-city',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-taichung',
#    'name': 'YouBike',
#    'location': {'latitude': 24.1477358,
#     'longitude': 120.6736482,
#     'city': '臺中市 Taichung City',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-taichung',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-tainan-city',
#    'name': 'YouBike',
#    'location': {'latitude': 22.9923,
#     'longitude': 120.185,
#     'city': '臺南市 Tainan City',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-tainan-city',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-taipei',
#    'name': 'YouBike',
#    'location': {'latitude': 25.0329636,
#     'longitude': 121.5654268,
#     'city': '台北市 Taipei City',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-taipei',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'youbike-taoyuan',
#    'name': 'YouBike',
#    'location': {'latitude': 24.9936281,
#     'longitude': 121.3009798,
#     'city': '桃園市 Taoyuan City',
#     'country': 'TW'},
#    'href': '/v2/networks/youbike-taoyuan',
#    'company': ['YouBike Co., Ltd.'],
#    'system': 'YouBike'},
#   {'id': 'yoy-san-luis-potosi',
#    'name': 'YOY - San Luis Potosi',
#    'location': {'latitude': 22.438,
#     'longitude': -100.514,
#     'city': 'San Luis Potosi',
#     'country': 'MX'},
#    'href': '/v2/networks/yoy-san-luis-potosi',
#    'company': ['Nextbike GmbH']},
#   {'id': 'yoy-san-luis-potosi-cancun',
#    'name': 'YOY - San Luis Potosi',
#    'location': {'latitude': 21.1675,
#     'longitude': -86.8498,
#     'city': 'Cancún',
#     'country': 'MX'},
#    'href': '/v2/networks/yoy-san-luis-potosi-cancun',
#    'company': ['Nextbike GmbH']},
#   {'id': 'yverdon-les-bains',
#    'name': 'Donkey Republic Yverdon-les-Bains',
#    'location': {'latitude': 46.7788,
#     'longitude': 6.6414,
#     'city': 'Yverdon-les-Bains',
#     'country': 'CH'},
#    'href': '/v2/networks/yverdon-les-bains',
#    'company': ['Donkey Republic'],
#    'gbfs_href': 'https://stables.donkey.bike/api/public/gbfs/2/donkey_yverdon-les-bains/gbfs.json'},
#   {'id': 'zebullo',
#    'name': 'ZébullO',
#    'location': {'latitude': 49.2628,
#     'longitude': 4.0347,
#     'city': 'Reims',
#     'country': 'FR'},
#    'href': '/v2/networks/zebullo',
#    'company': ['Ecovelo'],
#    'system': 'Ecovelo',
#    'ebikes': True,
#    'gbfs_href': 'https://api.gbfs.v2.2.ecovelo.mobi/zebullo/gbfs.json'},
#   {'id': 'zena-by-bike',
#    'name': 'Zena By Bike',
#    'location': {'latitude': 44.40430089372731,
#     'longitude': 8.92908986230462,
#     'city': 'Genova',
#     'country': 'IT'},
#    'href': '/v2/networks/zena-by-bike',
#    'company': ['Bicincitta Italia S.r.l.'],
#    'system': 'Weelo'},
#   {'id': 'zoov-paris-sud',
#    'name': 'Zoov',
#    'location': {'latitude': 48.7429,
#     'longitude': 2.238,
#     'city': 'Paris Sud',
#     'country': 'FR'},
#    'href': '/v2/networks/zoov-paris-sud',
#    'company': ['Fifteen SAS'],
#    'source': 'https://www.data.gouv.fr/fr/datasets/r/4646ba01-4fe0-4cd8-91d3-09e204bbaf86',
#    'license': {'name': 'Open Data Commons Open Database License (ODbL)',
#     'url': 'http://opendatacommons.org/licenses/odbl/summary/'},
#    'gbfs_href': 'https://gateway.prod.zoov.io/gbfs/2.2/saclay/en/gbfs.json?key=NGFlMjU3MDUtNDk5My00MTM4LTk1ZjctNmNlNDM1MWQ0NjE1'}]}

# %%
# Use pprint for a cleaner look at the df
pprint(city_bike_networks)
# Out:
# {'networks': [{'company': ['Careem'],
#                'gbfs_href': 'https://dubai.publicbikesystem.net/customer/gbfs/v2/en/gbfs.json',
#                'href': '/v2/networks/abu-dhabi-careem-bike',
#                'id': 'abu-dhabi-careem-bike',
#                'location': {'city': 'Abu Dhabi',
#                             'country': 'AE',
#                             'latitude': 24.4866,
#                             'longitude': 54.3728},
#                'name': 'Abu Dhabi Careem BIKE'},
#               {'company': ['PBSC Urban Solutions'],
#                'gbfs_href': 'https://saguenay.publicbikesystem.net/customer/gbfs/v2/gbfs.json',
#                'href': '/v2/networks/acces-velo-saguenay',
#                'id': 'acces-velo-saguenay',
#                'location': {'city': 'Saguenay',
#                             'country': 'CA',
#                             'latitude': 48.433333,
#                             'longitude': -71.083333},
#                'name': 'Accès Vélo'},
#               {'company': ['阿克苏公共服务'],
#                'href': '/v2/networks/aksu',
#                'id': 'aksu',
#                'location': {'city': '阿克苏市 (Aksu City)',
#                             'country': 'CN',
#                             'latitude': 41.1664,
#                             'longitude': 80.2617},
#                'name': 'Aksu'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/alba',
#                'id': 'alba',
#                'location': {'city': 'Alba',
#                             'country': 'IT',
#                             'latitude': 44.716667,
#                             'longitude': 8.083333},
#                'name': 'Alba',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=139',
#                'system': 'Bicincittà'},
#               {'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#                'href': '/v2/networks/albabici',
#                'id': 'albabici',
#                'location': {'city': 'Albacete',
#                             'country': 'ES',
#                             'latitude': 38.9943,
#                             'longitude': -1.8602},
#                'name': 'AlbaBici',
#                'system': 'bicicard'},
#               {'company': ['Município de Almeirim', 'Wegoshare, Lda'],
#                'ebikes': True,
#                'href': '/v2/networks/algira',
#                'id': 'algira',
#                'location': {'city': 'Almeirim',
#                             'country': 'PT',
#                             'latitude': 39.2082,
#                             'longitude': -8.6252},
#                'name': 'AlGira'},
#               {'company': ['Velobike.kz, LLP', 'Smoove'],
#                'href': '/v2/networks/almatybike',
#                'id': 'almatybike',
#                'location': {'city': 'Almaty',
#                             'country': 'KZ',
#                             'latitude': 43.239101,
#                             'longitude': 76.9268076},
#                'name': 'Almatybike',
#                'system': 'Velobike'},
#               {'company': ['Leonbici Nextbike Gmbh Y Autobuses Urbanos De Leon '
#                            'S.a. Ute'],
#                'href': '/v2/networks/alsa-nextbike-leon',
#                'id': 'alsa-nextbike-leon',
#                'location': {'city': 'León',
#                             'country': 'ES',
#                             'latitude': 42.5987263,
#                             'longitude': -5.5670959},
#                'name': 'Alsa nextbike León',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-badalona',
#                'id': 'ambici-badalona',
#                'location': {'city': 'Badalona',
#                             'country': 'ES',
#                             'latitude': 41.447,
#                             'longitude': 2.245},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-castelldefels',
#                'id': 'ambici-castelldefels',
#                'location': {'city': 'Castelldefels',
#                             'country': 'ES',
#                             'latitude': 41.2816,
#                             'longitude': 1.97678},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-cornella-de-llobregat',
#                'id': 'ambici-cornella-de-llobregat',
#                'location': {'city': 'Cornellà de Llobregat',
#                             'country': 'ES',
#                             'latitude': 41.3585,
#                             'longitude': 2.07081},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-el-prat-de-llobregat',
#                'id': 'ambici-el-prat-de-llobregat',
#                'location': {'city': 'El Prat de Llobregat',
#                             'country': 'ES',
#                             'latitude': 41.3239,
#                             'longitude': 2.09317},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-esplugues-de-llobregat',
#                'id': 'ambici-esplugues-de-llobregat',
#                'location': {'city': 'Esplugues de Llobregat',
#                             'country': 'ES',
#                             'latitude': 41.3771,
#                             'longitude': 2.08938},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-gava',
#                'id': 'ambici-gava',
#                'location': {'city': 'Gavà',
#                             'country': 'ES',
#                             'latitude': 41.303,
#                             'longitude': 2.00269},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-molins-de-rei',
#                'id': 'ambici-molins-de-rei',
#                'location': {'city': 'Molins de Rei',
#                             'country': 'ES',
#                             'latitude': 41.4132,
#                             'longitude': 2.02037},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-sant-boi-de-llobregat',
#                'id': 'ambici-sant-boi-de-llobregat',
#                'location': {'city': 'Sant Boi de Llobregat',
#                             'country': 'ES',
#                             'latitude': 41.3458,
#                             'longitude': 2.03404},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-sant-joan-despi',
#                'id': 'ambici-sant-joan-despi',
#                'location': {'city': 'Sant Joan Despí',
#                             'country': 'ES',
#                             'latitude': 41.368,
#                             'longitude': 2.05635},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-sant-just-desvern',
#                'id': 'ambici-sant-just-desvern',
#                'location': {'city': 'Sant Just Desvern',
#                             'country': 'ES',
#                             'latitude': 41.3807,
#                             'longitude': 2.07496},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-santa-coloma-de-gramenet',
#                'id': 'ambici-santa-coloma-de-gramenet',
#                'location': {'city': 'Santa Coloma de Gramenet',
#                             'country': 'ES',
#                             'latitude': 41.4459,
#                             'longitude': 2.21033},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Nextbike GmbH',
#                            'TIER Mobility SE',
#                            'Transports Metropolitans de Barcelona',
#                            'Projectes i Serveis de Mobilitat S.A'],
#                'href': '/v2/networks/ambici-viladecans',
#                'id': 'ambici-viladecans',
#                'location': {'city': 'Viladecans',
#                             'country': 'ES',
#                             'latitude': 41.3165,
#                             'longitude': 2.01306},
#                'name': 'Ambici',
#                'system': 'Ambici'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/andria',
#                'id': 'andria',
#                'location': {'city': 'Andria',
#                             'country': 'IT',
#                             'latitude': 41.224346932834,
#                             'longitude': 16.296983922753956},
#                'name': 'Andria in Bici',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=192',
#                'system': 'Bicincittà'},
#               {'company': ['阿克苏公共服务'],
#                'href': '/v2/networks/aral',
#                'id': 'aral',
#                'location': {'city': '阿拉尔市 (Aral)',
#                             'country': 'CN',
#                             'latitude': 40.5577,
#                             'longitude': 81.2879},
#                'name': 'Aral'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/arbike',
#                'id': 'arbike',
#                'location': {'city': 'Arezzo',
#                             'country': 'IT',
#                             'latitude': 43.473333,
#                             'longitude': 11.87},
#                'name': 'ARbike',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=84',
#                'system': 'Bicincittà'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/arriva-nitra',
#                'id': 'arriva-nitra',
#                'location': {'city': 'Nitra',
#                             'country': 'SK',
#                             'latitude': 48.3088,
#                             'longitude': 18.0783},
#                'name': 'Arriva'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/arval-scandicci',
#                'id': 'arval-scandicci',
#                'location': {'city': 'Scandicci',
#                             'country': 'IT',
#                             'latitude': 43.7701,
#                             'longitude': 11.1592},
#                'name': 'ARVAL',
#                'system': 'Nextbike'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/ascoli-piceno',
#                'id': 'ascoli-piceno',
#                'location': {'city': 'Ascoli Piceno',
#                             'country': 'IT',
#                             'latitude': 42.85,
#                             'longitude': 13.583333},
#                'name': 'Ascoli Piceno',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=73',
#                'system': 'Bicincittà'},
#               {'company': ['Brainbox Technology', 'Smoove SAS'],
#                'href': '/v2/networks/athens-bikes',
#                'id': 'athens-bikes',
#                'location': {'city': 'Athens',
#                             'country': 'GR',
#                             'latitude': 37.9838,
#                             'longitude': 23.7275},
#                'name': 'AthensBikes',
#                'system': 'EasyBike'},
#               {'company': ['BCycle, LLC'],
#                'gbfs_href': 'https://gbfs.bcycle.com/bcycle_austin/gbfs.json',
#                'href': '/v2/networks/austin',
#                'id': 'austin',
#                'location': {'city': 'Austin, TX',
#                             'country': 'US',
#                             'latitude': 30.26408,
#                             'longitude': -97.74355},
#                'name': 'ATX MetroBike',
#                'system': 'BCycle'},
#               {'company': ['Fifteen SAS'],
#                'href': '/v2/networks/auxrmlevelo',
#                'id': 'auxrmlevelo',
#                'location': {'city': 'Auxerre',
#                             'country': 'FR',
#                             'latitude': 47.797221,
#                             'longitude': 3.572376},
#                'name': 'AuxR_M le vélo',
#                'system': 'Fifteen'},
#               {'company': ['PBSC Urban Solutions'],
#                'gbfs_href': 'https://quebec.publicbikesystem.net/customer/gbfs/v2/gbfs.json',
#                'href': '/v2/networks/avelo-quebec',
#                'id': 'avelo-quebec',
#                'location': {'city': 'Québec',
#                             'country': 'CA',
#                             'latitude': 46.81305,
#                             'longitude': -71.2168},
#                'name': 'àVélo'},
#               {'company': ['BCycle, LLC'],
#                'gbfs_href': 'https://gbfs.bcycle.com/bcycle_aventura/gbfs.json',
#                'href': '/v2/networks/aventura',
#                'id': 'aventura',
#                'location': {'city': 'Aventura, FL',
#                             'country': 'US',
#                             'latitude': 25.95711,
#                             'longitude': -80.1395},
#                'name': 'Aventura BCycle',
#                'system': 'BCycle'},
#               {'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#                'href': '/v2/networks/aviles-en-bici',
#                'id': 'aviles-en-bici',
#                'location': {'city': 'Avilés',
#                             'country': 'ES',
#                             'latitude': 43.5554,
#                             'longitude': -5.9222},
#                'name': 'Avilés en Bici',
#                'system': 'bicicard'},
#               {'company': ['nextbike GmbH'],
#                'gbfs_href': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rh/gbfs.json',
#                'href': '/v2/networks/aw-bike',
#                'id': 'aw-bike',
#                'location': {'city': 'Ahrweiler',
#                             'country': 'DE',
#                             'latitude': 50.5452,
#                             'longitude': 7.1212},
#                'name': 'AW-bike Ahrweiler'},
#               {'company': ['Baksi Bike Sharing System'],
#                'href': '/v2/networks/baksi-antalya',
#                'id': 'baksi-antalya',
#                'location': {'city': 'Antalya',
#                             'country': 'TR',
#                             'latitude': 36.862048,
#                             'longitude': 30.638866},
#                'name': 'Baksi',
#                'system': 'Baksi'},
#               {'company': ['Baksi Bike Sharing System'],
#                'href': '/v2/networks/baksi-cabis',
#                'id': 'baksi-cabis',
#                'location': {'city': 'Çanakkale',
#                             'country': 'TR',
#                             'latitude': 40.1531,
#                             'longitude': 26.4146},
#                'name': 'Çabis',
#                'system': 'Baksi'},
#               {'company': ['Baksi Bike Sharing System'],
#                'href': '/v2/networks/baksi-nilesplit',
#                'id': 'baksi-nilesplit',
#                'location': {'city': 'Nilüfer',
#                             'country': 'TR',
#                             'latitude': 40.2127,
#                             'longitude': 28.9627},
#                'name': 'Nilesplit',
#                'system': 'Baksi'},
#               {'company': ['Smoove'],
#                'href': '/v2/networks/batumvelo',
#                'id': 'batumvelo',
#                'location': {'city': 'Batumi',
#                             'country': 'GE',
#                             'latitude': 41.660906,
#                             'longitude': 41.678835},
#                'name': 'Batumvelo',
#                'system': 'Smoove'},
#               {'company': ['Motivate LLC'],
#                'gbfs_href': 'https://gbfs.baywheels.com/gbfs/gbfs.json',
#                'href': '/v2/networks/bay-wheels',
#                'id': 'bay-wheels',
#                'location': {'city': 'San Francisco Bay Area, CA',
#                             'country': 'US',
#                             'latitude': 37.7141454,
#                             'longitude': -122.25},
#                'name': 'Bay Wheels'},
#               {'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#                'href': '/v2/networks/bealler',
#                'id': 'bealler',
#                'location': {'city': 'Aller',
#                             'country': 'ES',
#                             'latitude': 43.1482,
#                             'longitude': -5.6295},
#                'name': 'Pedaleando por Aller (BeALLER)',
#                'system': 'bicicard'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/belfastbikes-belfast',
#                'id': 'belfastbikes-belfast',
#                'location': {'city': 'Belfast',
#                             'country': 'GB',
#                             'latitude': 54.5969,
#                             'longitude': -5.92918},
#                'name': 'BelfastBikes',
#                'system': 'Nextbike'},
#               {'company': ['BCycle, LLC'],
#                'gbfs_href': 'https://gbfs.bcycle.com/bcycle_bentonville/gbfs.json',
#                'href': '/v2/networks/bentonville',
#                'id': 'bentonville',
#                'location': {'city': 'Bentonville, AR',
#                             'country': 'US',
#                             'latitude': 36.3605,
#                             'longitude': -94.1996},
#                'name': 'Bentonville BCycle',
#                'system': 'BCycle'},
#               {'company': ['Urban Sharing AS'],
#                'gbfs_href': 'https://gbfs.urbansharing.com/bergenbysykkel.no/gbfs.json',
#                'href': '/v2/networks/bergen-bysykkel',
#                'id': 'bergen-bysykkel',
#                'location': {'city': 'Bergen',
#                             'country': 'NO',
#                             'latitude': 60.391263,
#                             'longitude': 5.322054},
#                'name': 'Bysykkel'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/bergisches-e-bike',
#                'id': 'bergisches-e-bike',
#                'location': {'city': 'Bergisches e-Bike',
#                             'country': 'DE',
#                             'latitude': 51.0192,
#                             'longitude': 7.18025},
#                'name': 'Bergisches e-Bike',
#                'system': 'Nextbike'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/BCP/gbfs.json',
#                'href': '/v2/networks/beryl-bcp',
#                'id': 'beryl-bcp',
#                'location': {'city': 'Bournemouth, Christchurch and Poole',
#                             'country': 'GB',
#                             'latitude': 50.7196,
#                             'longitude': -1.8734},
#                'name': 'Beryl - Bournemouth, Christchurch and Poole'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Brighton/gbfs.json',
#                'href': '/v2/networks/beryl-brighton',
#                'id': 'beryl-brighton',
#                'location': {'city': 'Brighton',
#                             'country': 'GB',
#                             'latitude': 50.8222,
#                             'longitude': -0.1403},
#                'name': 'Beryl - Brighton'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Cornwall/gbfs.json',
#                'href': '/v2/networks/beryl-cornwall',
#                'id': 'beryl-cornwall',
#                'location': {'city': 'Cornwall',
#                             'country': 'GB',
#                             'latitude': 50.2616,
#                             'longitude': -5.051},
#                'name': 'Beryl - Cornwall'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Weymouth/gbfs.json',
#                'href': '/v2/networks/beryl-dorchester-weymouth-portland',
#                'id': 'beryl-dorchester-weymouth-portland',
#                'location': {'city': 'Dorchester, Weymouth and Portland',
#                             'country': 'GB',
#                             'latitude': 50.6085,
#                             'longitude': -2.454},
#                'name': 'Beryl - Dorchester, Weymouth and Portland'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Eastleigh/gbfs.json',
#                'href': '/v2/networks/beryl-eastleigh',
#                'id': 'beryl-eastleigh',
#                'location': {'city': 'Eastleigh',
#                             'country': 'GB',
#                             'latitude': 50.9691,
#                             'longitude': -1.3603},
#                'name': 'Beryl - Eastleigh'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Greater_Manchester/gbfs.json',
#                'href': '/v2/networks/beryl-greater-manchester',
#                'id': 'beryl-greater-manchester',
#                'location': {'city': 'Greater Manchester',
#                             'country': 'GB',
#                             'latitude': 53.4795,
#                             'longitude': -2.2436},
#                'name': 'Beryl - Greater Manchester'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Guildford/gbfs.json',
#                'href': '/v2/networks/beryl-guildford',
#                'id': 'beryl-guildford',
#                'location': {'city': 'Guildford',
#                             'country': 'GB',
#                             'latitude': 51.2397,
#                             'longitude': -0.5764},
#                'name': 'Beryl - Guildford'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Hereford/gbfs.json',
#                'href': '/v2/networks/beryl-hereford',
#                'id': 'beryl-hereford',
#                'location': {'city': 'Hereford',
#                             'country': 'GB',
#                             'latitude': 52.0549,
#                             'longitude': -2.7156},
#                'name': 'Beryl - Hereford'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Hertsmere/gbfs.json',
#                'href': '/v2/networks/beryl-hertsmere',
#                'id': 'beryl-hertsmere',
#                'location': {'city': 'Hertsmere',
#                             'country': 'GB',
#                             'latitude': 51.6577,
#                             'longitude': -0.2695},
#                'name': 'Beryl - Hertsmere'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Leeds/gbfs.json',
#                'href': '/v2/networks/beryl-leeds',
#                'id': 'beryl-leeds',
#                'location': {'city': 'Leeds',
#                             'country': 'GB',
#                             'latitude': 53.7971,
#                             'longitude': -1.5438},
#                'name': 'Beryl - Leeds'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Norwich/gbfs.json',
#                'href': '/v2/networks/beryl-norwich',
#                'id': 'beryl-norwich',
#                'location': {'city': 'Norwich',
#                             'country': 'GB',
#                             'latitude': 52.6288,
#                             'longitude': 1.2934},
#                'name': 'Beryl - Norwich'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Plymouth/gbfs.json',
#                'href': '/v2/networks/beryl-plymouth',
#                'id': 'beryl-plymouth',
#                'location': {'city': 'Plymouth',
#                             'country': 'GB',
#                             'latitude': 50.3714,
#                             'longitude': -4.1421},
#                'name': 'Beryl - Plymouth'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Stevenage/gbfs.json',
#                'href': '/v2/networks/beryl-stevenage',
#                'id': 'beryl-stevenage',
#                'location': {'city': 'Stevenage',
#                             'country': 'GB',
#                             'latitude': 51.9059,
#                             'longitude': -0.1905},
#                'name': 'Beryl - Stevenage'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Watford/gbfs.json',
#                'href': '/v2/networks/beryl-watford',
#                'id': 'beryl-watford',
#                'location': {'city': 'Watford',
#                             'country': 'GB',
#                             'latitude': 51.6556,
#                             'longitude': -0.3953},
#                'name': 'Beryl - Watford'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/West_Midlands/gbfs.json',
#                'href': '/v2/networks/beryl-west-midlands',
#                'id': 'beryl-west-midlands',
#                'location': {'city': 'West Midlands',
#                             'country': 'GB',
#                             'latitude': 52.4798,
#                             'longitude': -1.9014},
#                'name': 'Beryl - West Midlands'},
#               {'company': ['Beryl'],
#                'gbfs_href': 'https://gbfs.beryl.cc/v2_2/Worcester/gbfs.json',
#                'href': '/v2/networks/beryl-worcester',
#                'id': 'beryl-worcester',
#                'location': {'city': 'Worcester',
#                             'country': 'GB',
#                             'latitude': 52.1912,
#                             'longitude': -2.2206},
#                'name': 'Beryl - Worcester'},
#               {'company': ['Município de Ovar',
#                            'Share2Go - Mobilidade Partilhada, Sociedade '
#                            'Unipessoal Lda'],
#                'ebikes': True,
#                'href': '/v2/networks/bia',
#                'id': 'bia',
#                'location': {'city': 'Ovar',
#                             'country': 'PT',
#                             'latitude': 40.8599,
#                             'longitude': -8.6246},
#                'name': 'BIA'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bianzone-in-bici',
#                'id': 'bianzone-in-bici',
#                'location': {'city': 'Bianzone',
#                             'country': 'IT',
#                             'latitude': 46.188197,
#                             'longitude': 10.109354},
#                'name': 'Bianzone in Bici',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=147',
#                'system': 'Bicincittà'},
#               {'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#                'href': '/v2/networks/biba',
#                'id': 'biba',
#                'location': {'city': 'Badajoz',
#                             'country': 'ES',
#                             'latitude': 38.878,
#                             'longitude': -6.9701},
#                'name': 'BiBa',
#                'system': 'bicicard'},
#               {'company': ['Movilidad Urbana Sostenible SLU'],
#                'href': '/v2/networks/bibo',
#                'id': 'bibo',
#                'location': {'city': 'Boadilla del Monte',
#                             'country': 'ES',
#                             'latitude': 40.4125,
#                             'longitude': -3.8909},
#                'name': 'BIBO'},
#               {'company': ['Ecospazio Logiss S.r.l.'],
#                'href': '/v2/networks/bici-bolzano',
#                'id': 'bici-bolzano',
#                'location': {'city': 'Bolzano',
#                             'country': 'IT',
#                             'latitude': 46.49,
#                             'longitude': 11.3401},
#                'name': 'Bici Bolzano'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bici-co',
#                'id': 'bici-co',
#                'location': {'city': 'Como',
#                             'country': 'IT',
#                             'latitude': 45.8080597,
#                             'longitude': 9.0851765},
#                'name': 'BICI&CO',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=157',
#                'system': 'Bicincittà'},
#               {'company': ['2K SYSTEMS, S.L.', 'Bike Works Naron'],
#                'href': '/v2/networks/bici-ferrol-terra',
#                'id': 'bici-ferrol-terra',
#                'location': {'city': 'Ferrol - Narón',
#                             'country': 'ES',
#                             'latitude': 43.4896,
#                             'longitude': -8.2193},
#                'name': 'BiciFerrolTerra'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bici-in-busto',
#                'id': 'bici-in-busto',
#                'location': {'city': 'Busto Arsizio',
#                             'country': 'IT',
#                             'latitude': 45.610555,
#                             'longitude': 8.852062},
#                'name': 'Bici in Busto',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=66',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bici-perugia',
#                'id': 'bici-perugia',
#                'location': {'city': 'Perugia',
#                             'country': 'IT',
#                             'latitude': 43.1107168,
#                             'longitude': 12.3908279},
#                'name': 'Bici Perugia',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=122',
#                'system': 'Bicincittà'},
#               {'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#                'href': '/v2/networks/bicialcazar',
#                'id': 'bicialcazar',
#                'location': {'city': 'Alcázar de San Juan',
#                             'country': 'ES',
#                             'latitude': 39.3901,
#                             'longitude': -3.2101},
#                'name': 'BiciAlcázar',
#                'system': 'bicicard'},
#               {'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#                'href': '/v2/networks/biciarousa',
#                'id': 'biciarousa',
#                'location': {'city': 'A Illa de Arousa',
#                             'country': 'ES',
#                             'latitude': 42.5521,
#                             'longitude': -8.8666},
#                'name': 'BiciArousa',
#                'system': 'bicicard'},
#               {'company': ['Servizos Urbanos Municipais de Arteixo, S. A.'],
#                'href': '/v2/networks/biciarteixo',
#                'id': 'biciarteixo',
#                'location': {'city': 'Arteixo',
#                             'country': 'ES',
#                             'latitude': 43.3053,
#                             'longitude': -8.5069},
#                'name': 'biciArteixo',
#                'system': 'Nextbike'},
#               {'company': ['Instituto Tecnológico de Castilla y León (ITCL)'],
#                'href': '/v2/networks/bicibur',
#                'id': 'bicibur',
#                'location': {'city': 'Burgos',
#                             'country': 'ES',
#                             'latitude': 42.34392,
#                             'longitude': -3.69697},
#                'name': 'BiciBur'},
#               {'company': ['Maquiver S.L.U.',
#                            'Ajuntament de Castelló de la Plana'],
#                'href': '/v2/networks/bicicas',
#                'id': 'bicicas',
#                'location': {'city': 'Castelló de la Plana',
#                             'country': 'ES',
#                             'latitude': 39.9856,
#                             'longitude': -0.0389},
#                'name': 'Bicicas'},
#               {'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#                'href': '/v2/networks/bicicletar',
#                'id': 'bicicletar',
#                'location': {'city': 'Fortaleza',
#                             'country': 'BR',
#                             'latitude': -3.7321944,
#                             'longitude': -38.510347},
#                'name': 'Bicicletar',
#                'system': 'Samba'},
#               {'company': ['PBSC Urban Solutions'],
#                'gbfs_href': 'https://acoruna.publicbikesystem.net/customer/gbfs/v2/gbfs.json',
#                'href': '/v2/networks/bicicorunha',
#                'id': 'bicicorunha',
#                'location': {'city': 'A Coruña',
#                             'country': 'ES',
#                             'latitude': 43.3623,
#                             'longitude': -8.4115},
#                'name': 'Bicicoruña'},
#               {'company': ['Mobilicidade Tecnologia LTD', 'Grupo Serttel LTDA'],
#                'href': '/v2/networks/bicicuenca',
#                'id': 'bicicuenca',
#                'location': {'city': 'Cuenca',
#                             'country': 'EC',
#                             'latitude': -2.897,
#                             'longitude': -79.0038},
#                'name': 'Bici Pública Cuenca',
#                'system': 'Samba'},
#               {'company': ['Promociones e Iniciativas Municipales de Elche, '
#                            'S.A.'],
#                'href': '/v2/networks/bicielx',
#                'id': 'bicielx',
#                'location': {'city': 'Elx',
#                             'country': 'ES',
#                             'latitude': 38.2665,
#                             'longitude': -0.7},
#                'name': 'Bicielx'},
#               {'company': ['JCDecaux'],
#                'href': '/v2/networks/bicikelj',
#                'id': 'bicikelj',
#                'license': {'name': 'Open Licence',
#                            'url': 'https://developer.jcdecaux.com/#/opendata/licence'},
#                'location': {'city': 'Ljubljana',
#                             'country': 'SI',
#                             'latitude': 46.05645089999999,
#                             'longitude': 14.5080702},
#                'name': 'Bicikelj',
#                'source': 'https://developer.jcdecaux.com',
#                'system': 'Cyclocity'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/bicilog',
#                'id': 'bicilog',
#                'location': {'city': 'Logroño',
#                             'country': 'ES',
#                             'latitude': 42.4658,
#                             'longitude': -2.4402},
#                'name': 'BiciLog',
#                'system': 'Nextbike'},
#               {'company': ['Empresa Municipal de Transportes de Madrid, S.A.'],
#                'href': '/v2/networks/bicimad',
#                'id': 'bicimad',
#                'location': {'city': 'Madrid',
#                             'country': 'ES',
#                             'latitude': 40.4168,
#                             'longitude': -3.7038},
#                'name': 'BiciMAD',
#                'source': 'https://mobilitylabs.emtmadrid.es/',
#                'system': 'bicimad'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicimia',
#                'id': 'bicimia',
#                'location': {'city': 'Brescia',
#                             'country': 'IT',
#                             'latitude': 45.5378,
#                             'longitude': 10.2173},
#                'name': 'bicimia',
#                'source': 'https://bicimia.bresciamobilita.it/frmLeStazioni.aspx?ID=40',
#                'system': 'Bicincittà'},
#               {'company': ['Movilidad Urbana Sostenible, S.L'],
#                'href': '/v2/networks/bicimislata',
#                'id': 'bicimislata',
#                'location': {'city': 'Mislata',
#                             'country': 'ES',
#                             'latitude': 39.4763,
#                             'longitude': -0.4182},
#                'name': 'BiciMislata',
#                'system': 'Nextbike'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-acquarica-del-capo',
#                'id': 'bicincitta-acquarica-del-capo',
#                'location': {'city': 'Acquarica del Capo',
#                             'country': 'IT',
#                             'latitude': 39.9144573,
#                             'longitude': 18.2450324},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=146',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-acquaviva-delle-fonti',
#                'id': 'bicincitta-acquaviva-delle-fonti',
#                'location': {'city': 'Acquaviva delle fonti',
#                             'country': 'IT',
#                             'latitude': 40.9303721,
#                             'longitude': 16.8414374},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=160',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-alghero',
#                'id': 'bicincitta-alghero',
#                'location': {'city': 'Alghero',
#                             'country': 'IT',
#                             'latitude': 40.5579517,
#                             'longitude': 8.319294900000001},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=237',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-assemini',
#                'id': 'bicincitta-assemini',
#                'location': {'city': 'Assemini',
#                             'country': 'IT',
#                             'latitude': 39.28956306007679,
#                             'longitude': 9.006601555294765},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=205',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-borgarello',
#                'id': 'bicincitta-borgarello',
#                'location': {'city': 'Borgarello',
#                             'country': 'IT',
#                             'latitude': 45.23963753440171,
#                             'longitude': 9.136150475640875},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=208',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-brancaleone',
#                'id': 'bicincitta-brancaleone',
#                'location': {'city': 'Brancaleone',
#                             'country': 'IT',
#                             'latitude': 37.9679084,
#                             'longitude': 16.0757749},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=104',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-carrara',
#                'id': 'bicincitta-carrara',
#                'location': {'city': 'Carrara',
#                             'country': 'IT',
#                             'latitude': 44.07731805550891,
#                             'longitude': 10.097172450401331},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=211',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-casaletto-spartano',
#                'id': 'bicincitta-casaletto-spartano',
#                'location': {'city': 'Casaletto Spartano',
#                             'country': 'IT',
#                             'latitude': 40.1532801,
#                             'longitude': 15.6211479},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=199',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-castel-guelfo-the-style-outlets',
#                'id': 'bicincitta-castel-guelfo-the-style-outlets',
#                'location': {'city': 'Castel Guelfo di Bologna',
#                             'country': 'IT',
#                             'latitude': 44.4328527,
#                             'longitude': 11.6750857},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=233',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-cesena',
#                'id': 'bicincitta-cesena',
#                'location': {'city': 'Cesena',
#                             'country': 'IT',
#                             'latitude': 44.1396438,
#                             'longitude': 12.2464292},
#                'name': 'Mi Muovo in bici',
#                'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=120',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-cisterna-di-latina',
#                'id': 'bicincitta-cisterna-di-latina',
#                'location': {'city': 'Cisterna di Latina',
#                             'country': 'IT',
#                             'latitude': 41.5754029,
#                             'longitude': 12.8284772},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=217',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-costa-blu',
#                'id': 'bicincitta-costa-blu',
#                'location': {'city': 'Montesilvano',
#                             'country': 'IT',
#                             'latitude': 42.5009,
#                             'longitude': 14.1282},
#                'name': 'Costa Blu',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=268',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-elmas',
#                'id': 'bicincitta-elmas',
#                'location': {'city': 'Elmas',
#                             'country': 'IT',
#                             'latitude': 39.2634329,
#                             'longitude': 9.0515805},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=218',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-ente-parco-del-circeo',
#                'id': 'bicincitta-ente-parco-del-circeo',
#                'location': {'city': 'Parco Nazionale del Circeo',
#                             'country': 'IT',
#                             'latitude': 41.3151015,
#                             'longitude': 13.0330782},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=135',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-ente-parco-di-montemarcello-magra',
#                'id': 'bicincitta-ente-parco-di-montemarcello-magra',
#                'location': {'city': 'Ente Parco Montemarcello Magra',
#                             'country': 'IT',
#                             'latitude': 44.1143897,
#                             'longitude': 9.9635986},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=132',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-ente-parco-san-rossore',
#                'id': 'bicincitta-ente-parco-san-rossore',
#                'location': {'city': 'Parco naturale Migliarino San Rossore '
#                                     'Massaciuccoli',
#                             'country': 'IT',
#                             'latitude': 43.723826,
#                             'longitude': 10.339509},
#                'name': 'Bicincittà',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=145',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-forli',
#                'id': 'bicincitta-forli',
#                'location': {'city': 'Forlì',
#                             'country': 'IT',
#                             'latitude': 44.2227398,
#                             'longitude': 12.0407312},
#                'name': 'Mi Muovo in Bici',
#                'source': 'http://www.mimuovoinbici.it/frmLeStazioni.aspx?ID=119',
#                'system': 'Bicincittà'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/bicincitta-gaeta',
#                'id': 'bicincitta-gaeta',
#                'location': {'city': 'Gaeta',
#                             'country': 'IT',
#                             'latitude': 41.209620965538036,
#                             'longitude': 13.584335125656139},
#                'name': 'Bicincittà',
# ...
#                             'longitude': -106.837002},
#                'name': 'WE-cycle'},
#               {'company': ['Comunicare S.r.l.'],
#                'href': '/v2/networks/we-love-bike',
#                'id': 'we-love-bike',
#                'location': {'city': 'Lodi',
#                             'country': 'IT',
#                             'latitude': 45.3097228,
#                             'longitude': 9.503715999999999},
#                'name': 'We Love bike',
#                'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=190',
#                'system': 'Bicincittà'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/westbike-erkelenz',
#                'id': 'westbike-erkelenz',
#                'location': {'city': 'Erkelenz',
#                             'country': 'DE',
#                             'latitude': 51.0753,
#                             'longitude': 6.31233},
#                'name': 'westBike',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/westbike-geilenkirchen',
#                'id': 'westbike-geilenkirchen',
#                'location': {'city': 'Geilenkirchen',
#                             'country': 'DE',
#                             'latitude': 50.9671,
#                             'longitude': 6.11886},
#                'name': 'westBike',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/westbike-heinsberg',
#                'id': 'westbike-heinsberg',
#                'location': {'city': 'Heinsberg',
#                             'country': 'DE',
#                             'latitude': 51.0597,
#                             'longitude': 6.11849},
#                'name': 'westBike',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/westbike-hueckelhoven',
#                'id': 'westbike-hueckelhoven',
#                'location': {'city': 'Hückelhoven',
#                             'country': 'DE',
#                             'latitude': 51.0529,
#                             'longitude': 6.21933},
#                'name': 'westBike',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/westbike-wegberg',
#                'id': 'westbike-wegberg',
#                'location': {'city': 'Wegberg',
#                             'country': 'DE',
#                             'latitude': 51.1427,
#                             'longitude': 6.2813},
#                'name': 'westBike',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/westcargo-bath',
#                'id': 'westcargo-bath',
#                'location': {'city': 'Bath',
#                             'country': 'GB',
#                             'latitude': 51.3814,
#                             'longitude': -2.35519},
#                'name': 'WESTcargo Bath',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/westcargo-bristol',
#                'id': 'westcargo-bristol',
#                'location': {'city': 'Bristol',
#                             'country': 'GB',
#                             'latitude': 51.4587,
#                             'longitude': -2.57355},
#                'name': 'WESTcargo Bristol',
#                'system': 'Nextbike'},
#               {'company': ['Open Source Bike Share'],
#                'href': '/v2/networks/whitebikes',
#                'id': 'whitebikes',
#                'location': {'city': 'Bratislava',
#                             'country': 'SK',
#                             'latitude': 48.149424,
#                             'longitude': 17.113922},
#                'name': 'WhiteBikes',
#                'system': 'OpenSourceBikeShare'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/wienmobil-rad',
#                'id': 'wienmobil-rad',
#                'location': {'city': 'Wien',
#                             'country': 'AT',
#                             'latitude': 48.2081743,
#                             'longitude': 16.3738189},
#                'name': 'WienMobil Rad',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/winsenrad',
#                'id': 'winsenrad',
#                'location': {'city': 'Winsen (Luhe)',
#                             'country': 'DE',
#                             'latitude': 53.3547,
#                             'longitude': 10.2067},
#                'name': 'WinsenRad',
#                'system': 'Nextbike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/wk-bike-bremen-bremen',
#                'id': 'wk-bike-bremen-bremen',
#                'location': {'city': 'Bremen',
#                             'country': 'DE',
#                             'latitude': 53.0781,
#                             'longitude': 8.80132},
#                'name': 'WK-Bike',
#                'system': 'Nextbike'},
#               {'company': ['Stony Brook University'],
#                'gbfs_href': 'https://sbu.publicbikesystem.net/customer/gbfs/v2/gbfs.json',
#                'href': '/v2/networks/wolf-ride-bike-share',
#                'id': 'wolf-ride-bike-share',
#                'location': {'city': 'Stony Brook',
#                             'country': 'US',
#                             'latitude': 40.9124,
#                             'longitude': -73.1249},
#                'name': 'Wolf Ride Bike Share (Stony Brook University)'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/wrm-wroclaw',
#                'id': 'wrm-wroclaw',
#                'location': {'city': 'Wrocław',
#                             'country': 'PL',
#                             'latitude': 51.1097,
#                             'longitude': 17.0485},
#                'name': 'WRM'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/wupsi',
#                'id': 'wupsi',
#                'location': {'city': 'Leverkusen',
#                             'country': 'DE',
#                             'latitude': 51.0732,
#                             'longitude': 7.00814},
#                'name': 'wupsiRad Leverkusen',
#                'system': 'Nextbike'},
#               {'company': ['西安城市公共自行车服务管理有'],
#                'href': '/v2/networks/xian-public-bicycle',
#                'id': 'xian-public-bicycle',
#                'location': {'city': "西安 (Xi'an)",
#                             'country': 'CN',
#                             'latitude': 34.2688,
#                             'longitude': 108.9458},
#                'name': "Xi'an Public Bicycle"},
#               {'company': ["Communauté d'Agglomération de La Rochelle"],
#                'href': '/v2/networks/yelo-velo',
#                'id': 'yelo-velo',
#                'license': {'name': 'Licence Ouverte',
#                            'url': 'https://www.etalab.gouv.fr/licence-ouverte-open-licence/'},
#                'location': {'city': 'La Rochelle',
#                             'country': 'FR',
#                             'latitude': 46.1591,
#                             'longitude': -1.1509},
#                'name': 'Yélo Vélo'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-chiayi-city',
#                'id': 'youbike-chiayi-city',
#                'location': {'city': '台灣 Chiayi City',
#                             'country': 'TW',
#                             'latitude': 23.4797,
#                             'longitude': 120.4397},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-hsinchu-city',
#                'id': 'youbike-hsinchu-city',
#                'location': {'city': '新竹市 Hsinchu City',
#                             'country': 'TW',
#                             'latitude': 24.8018,
#                             'longitude': 120.9714},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-hsinchu-county',
#                'id': 'youbike-hsinchu-county',
#                'location': {'city': '新竹縣 Hsinchu County',
#                             'country': 'TW',
#                             'latitude': 24.8269,
#                             'longitude': 121.0129},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-hsinchu-science-park',
#                'id': 'youbike-hsinchu-science-park',
#                'location': {'city': '新竹科學工業園區 Hsinchu Science Park',
#                             'country': 'TW',
#                             'latitude': 24.7818,
#                             'longitude': 121.005},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-kaohsiung-city',
#                'id': 'youbike-kaohsiung-city',
#                'location': {'city': '高雄市 Kaohsiung City',
#                             'country': 'TW',
#                             'latitude': 22.6314,
#                             'longitude': 120.3018},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-miaoli-county',
#                'id': 'youbike-miaoli-county',
#                'location': {'city': '台灣 Miaoli County',
#                             'country': 'TW',
#                             'latitude': 24.5648,
#                             'longitude': 120.8185},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-new-taipei',
#                'id': 'youbike-new-taipei',
#                'location': {'city': '新北市 New Taipei',
#                             'country': 'TW',
#                             'latitude': 25.0169826,
#                             'longitude': 121.4627868},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-pingtung-county',
#                'id': 'youbike-pingtung-county',
#                'location': {'city': '屏東縣 Pingtung County',
#                             'country': 'TW',
#                             'latitude': 22.683,
#                             'longitude': 120.4879},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-putian-city',
#                'id': 'youbike-putian-city',
#                'location': {'city': '莆田市 (Putian City)',
#                             'country': 'CN',
#                             'latitude': 25.4504,
#                             'longitude': 119.0126},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-taichung',
#                'id': 'youbike-taichung',
#                'location': {'city': '臺中市 Taichung City',
#                             'country': 'TW',
#                             'latitude': 24.1477358,
#                             'longitude': 120.6736482},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-tainan-city',
#                'id': 'youbike-tainan-city',
#                'location': {'city': '臺南市 Tainan City',
#                             'country': 'TW',
#                             'latitude': 22.9923,
#                             'longitude': 120.185},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-taipei',
#                'id': 'youbike-taipei',
#                'location': {'city': '台北市 Taipei City',
#                             'country': 'TW',
#                             'latitude': 25.0329636,
#                             'longitude': 121.5654268},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['YouBike Co., Ltd.'],
#                'href': '/v2/networks/youbike-taoyuan',
#                'id': 'youbike-taoyuan',
#                'location': {'city': '桃園市 Taoyuan City',
#                             'country': 'TW',
#                             'latitude': 24.9936281,
#                             'longitude': 121.3009798},
#                'name': 'YouBike',
#                'system': 'YouBike'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/yoy-san-luis-potosi',
#                'id': 'yoy-san-luis-potosi',
#                'location': {'city': 'San Luis Potosi',
#                             'country': 'MX',
#                             'latitude': 22.438,
#                             'longitude': -100.514},
#                'name': 'YOY - San Luis Potosi'},
#               {'company': ['Nextbike GmbH'],
#                'href': '/v2/networks/yoy-san-luis-potosi-cancun',
#                'id': 'yoy-san-luis-potosi-cancun',
#                'location': {'city': 'Cancún',
#                             'country': 'MX',
#                             'latitude': 21.1675,
#                             'longitude': -86.8498},
#                'name': 'YOY - San Luis Potosi'},
#               {'company': ['Donkey Republic'],
#                'gbfs_href': 'https://stables.donkey.bike/api/public/gbfs/2/donkey_yverdon-les-bains/gbfs.json',
#                'href': '/v2/networks/yverdon-les-bains',
#                'id': 'yverdon-les-bains',
#                'location': {'city': 'Yverdon-les-Bains',
#                             'country': 'CH',
#                             'latitude': 46.7788,
#                             'longitude': 6.6414},
#                'name': 'Donkey Republic Yverdon-les-Bains'},
#               {'company': ['Ecovelo'],
#                'ebikes': True,
#                'gbfs_href': 'https://api.gbfs.v2.2.ecovelo.mobi/zebullo/gbfs.json',
#                'href': '/v2/networks/zebullo',
#                'id': 'zebullo',
#                'location': {'city': 'Reims',
#                             'country': 'FR',
#                             'latitude': 49.2628,
#                             'longitude': 4.0347},
#                'name': 'ZébullO',
#                'system': 'Ecovelo'},
#               {'company': ['Bicincitta Italia S.r.l.'],
#                'href': '/v2/networks/zena-by-bike',
#                'id': 'zena-by-bike',
#                'location': {'city': 'Genova',
#                             'country': 'IT',
#                             'latitude': 44.40430089372731,
#                             'longitude': 8.92908986230462},
#                'name': 'Zena By Bike',
#                'system': 'Weelo'},
#               {'company': ['Fifteen SAS'],
#                'gbfs_href': 'https://gateway.prod.zoov.io/gbfs/2.2/saclay/en/gbfs.json?key=NGFlMjU3MDUtNDk5My00MTM4LTk1ZjctNmNlNDM1MWQ0NjE1',
#                'href': '/v2/networks/zoov-paris-sud',
#                'id': 'zoov-paris-sud',
#                'license': {'name': 'Open Data Commons Open Database License '
#                                    '(ODbL)',
#                            'url': 'http://opendatacommons.org/licenses/odbl/summary/'},
#                'location': {'city': 'Paris Sud',
#                             'country': 'FR',
#                             'latitude': 48.7429,
#                             'longitude': 2.238},
#                'name': 'Zoov',
#                'source': 'https://www.data.gouv.fr/fr/datasets/r/4646ba01-4fe0-4cd8-91d3-09e204bbaf86'}]}

# %%
# Filter networks in Italy for Rome. 
# Find the ID for a major city like Rome or Venice
italy_networks = [network for network in city_bike_networks['networks'] if network['location']['city'] == 'Milano']
italy_networks
# Out:
# [{'id': 'bikemi',
#   'name': 'BikeMi',
#   'location': {'latitude': 45.4654542,
#    'longitude': 9.186516,
#    'city': 'Milano',
#    'country': 'IT'},
#   'href': '/v2/networks/bikemi',
#   'company': ['IGP S.p.A.'],
#   'ebikes': True,
#   'gbfs_href': 'https://gbfs.urbansharing.com/bikemi.com/gbfs.json'}]

# %%
# Use the id to find Milan
network_id = 'bikemi'
network_json = requests.get("http://api.citybik.es/v2/networks/"+network_id).json()
pprint(network_json)
# Out:
# {'network': {'company': ['IGP S.p.A.'],
#              'ebikes': True,
#              'gbfs_href': 'https://gbfs.urbansharing.com/bikemi.com/gbfs.json',
#              'href': '/v2/networks/bikemi',
#              'id': 'bikemi',
#              'location': {'city': 'Milano',
#                           'country': 'IT',
#                           'latitude': 45.4654542,
#                           'longitude': 9.186516},
#              'name': 'BikeMi',
#              'stations': [{'empty_slots': 6,
#                            'extra': {'address': 'Via Tolstoi civ.53',
#                                      'ebikes': 6,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 14,
#                                      'rental_uris': {'android': 'bikemi://stations/2255',
#                                                      'ios': 'bikemi://stations/2255'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2255'},
#                            'free_bikes': 20,
#                            'id': '00ac8507b9c64010d723191c2aa43c6c',
#                            'latitude': 45.453710246267775,
#                            'longitude': 9.149430356583878,
#                            'name': '368 - Tolstoi - Lorenteggio',
#                            'timestamp': '2025-02-06T20:49:44.915500Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': "piazza Duca d'Aosta ang. p.za "
#                                                 'IV Novembre',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 8,
#                                      'rental_uris': {'android': 'bikemi://stations/1945',
#                                                      'ios': 'bikemi://stations/1945'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '1945'},
#                            'free_bikes': 8,
#                            'id': '024840e7637ee07c1359c5411d646605',
#                            'latitude': 45.48545592591419,
#                            'longitude': 9.202571958303452,
#                            'name': '25 - Centrale 1',
#                            'timestamp': '2025-02-06T20:49:44.945428Z'},
#                           {'empty_slots': 0,
#                            'extra': {'address': 'Coni Zugna Solari',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 25,
#                                      'rental_uris': {'android': 'bikemi://stations/2080',
#                                                      'ios': 'bikemi://stations/2080'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2080'},
#                            'free_bikes': 25,
#                            'id': '0362ab13bb70f49ed16e658b7312333c',
#                            'latitude': 45.4570790609292,
#                            'longitude': 9.16801035404205,
#                            'name': '161 - Coni Zugna - Solari',
#                            'timestamp': '2025-02-06T20:49:44.919206Z'},
#                           {'empty_slots': 7,
#                            'extra': {'address': 'Largo La Foppa angolo '
#                                                 'Garibaldi',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 14,
#                                      'rental_uris': {'android': 'bikemi://stations/1936',
#                                                      'ios': 'bikemi://stations/1936'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '1936'},
#                            'free_bikes': 14,
#                            'id': '03f63abd5b085802c6088b521878692e',
#                            'latitude': 45.4775338860989,
#                            'longitude': 9.18455958366394,
#                            'name': '16 - Moscova',
#                            'timestamp': '2025-02-06T20:49:44.945565Z'},
#                           {'empty_slots': 15,
#                            'extra': {'address': 'Via Tertulliano civ. 35',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 9,
#                                      'rental_uris': {'android': 'bikemi://stations/2244',
#                                                      'ios': 'bikemi://stations/2244'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 27,
#                                      'uid': '2244'},
#                            'free_bikes': 11,
#                            'id': '05559030ad647472f5f7ac0735f725ba',
#                            'latitude': 45.449209375464,
#                            'longitude': 9.21804812568328,
#                            'name': '359 - Tertulliano - Caroncini',
#                            'timestamp': '2025-02-06T20:49:44.915729Z'},
#                           {'empty_slots': 16,
#                            'extra': {'address': 'Piazza Cordusio fr civ 2',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 13,
#                                      'rental_uris': {'android': 'bikemi://stations/2237',
#                                                      'ios': 'bikemi://stations/2237'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2237'},
#                            'free_bikes': 13,
#                            'id': '0559534ff04468a1f3ee571fec03e9ab',
#                            'latitude': 45.4655540606139,
#                            'longitude': 9.18622358536001,
#                            'name': '352 - Cordusio',
#                            'timestamp': '2025-02-06T20:49:44.915838Z'},
#                           {'empty_slots': 15,
#                            'extra': {'address': 'Bertarelli',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 6,
#                                      'rental_uris': {'android': 'bikemi://stations/1985',
#                                                      'ios': 'bikemi://stations/1985'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '1985'},
#                            'free_bikes': 8,
#                            'id': '07c23bdde633162101cf1cdc962cf971',
#                            'latitude': 45.4585296153456,
#                            'longitude': 9.187534153461456,
#                            'name': '65 - Bertarelli',
#                            'timestamp': '2025-02-06T20:49:44.944658Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'p.za Tricolore lato via '
#                                                 'Bianca Maria',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 17,
#                                      'rental_uris': {'android': 'bikemi://stations/1944',
#                                                      'ios': 'bikemi://stations/1944'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 27,
#                                      'uid': '1944'},
#                            'free_bikes': 17,
#                            'id': '08dedb64715412fb58628898aba70e72',
#                            'latitude': 45.4677795495416,
#                            'longitude': 9.205842912197113,
#                            'name': '24 - Tricolore',
#                            'timestamp': '2025-02-06T20:49:44.945443Z'},
#                           {'empty_slots': 10,
#                            'extra': {'address': "Via Ca' Granda ang. viale "
#                                                 'Fulvio Testi',
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 17,
#                                      'rental_uris': {'android': 'bikemi://stations/2197',
#                                                      'ios': 'bikemi://stations/2197'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2197'},
#                            'free_bikes': 18,
#                            'id': '0906ee8ee93ce2ac8af8239242b58359',
#                            'latitude': 45.506626046713706,
#                            'longitude': 9.200289733707905,
#                            'name': "313 - Ca' Granda - F. Testi",
#                            'timestamp': '2025-02-06T20:49:44.916499Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'XXII Marzo',
#                                      'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 19,
#                                      'rental_uris': {'android': 'bikemi://stations/2050',
#                                                      'ios': 'bikemi://stations/2050'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2050'},
#                            'free_bikes': 23,
#                            'id': '0912f6d76376f0ebbe80edb06986c98d',
#                            'latitude': 45.46218875996901,
#                            'longitude': 9.212489426136017,
#                            'name': '130 - XXII Marzo',
#                            'timestamp': '2025-02-06T20:49:44.944056Z'},
#                           {'empty_slots': 0,
#                            'extra': {'address': 'Lazio - Vasari - Morosini',
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 25,
#                                      'rental_uris': {'android': 'bikemi://stations/2058',
#                                                      'ios': 'bikemi://stations/2058'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2058'},
#                            'free_bikes': 26,
#                            'id': '0a6536775160e100f74f031a25e546b8',
#                            'latitude': 45.45533213750292,
#                            'longitude': 9.20820727944374,
#                            'name': '139 - Lazio - Vasari - Morosini',
#                            'timestamp': '2025-02-06T20:49:44.918986Z'},
#                           {'empty_slots': 18,
#                            'extra': {'address': 'Piazza Duomo angolo via Ugo '
#                                                 'Foscolo',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 11,
#                                      'rental_uris': {'android': 'bikemi://stations/2234',
#                                                      'ios': 'bikemi://stations/2234'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 33,
#                                      'uid': '2234'},
#                            'free_bikes': 11,
#                            'id': '0a889cf6e92a7059f99335f13ff176de',
#                            'latitude': 45.4647602708966,
#                            'longitude': 9.1911407472792,
#                            'name': '351 - Duomo 2 - Foscolo',
#                            'timestamp': '2025-02-06T20:49:44.915885Z'},
#                           {'empty_slots': 28,
#                            'extra': {'address': 'largo Augusto ang. Via '
#                                                 'Verziere',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 1,
#                                      'rental_uris': {'android': 'bikemi://stations/1981',
#                                                      'ios': 'bikemi://stations/1981'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '1981'},
#                            'free_bikes': 1,
#                            'id': '0b8fb6355d969a1e1671d304a0cca311',
#                            'latitude': 45.4630080516828,
#                            'longitude': 9.197395017426606,
#                            'name': '61 - Augusto',
#                            'timestamp': '2025-02-06T20:49:44.944719Z'},
#                           {'empty_slots': 15,
#                            'extra': {'address': 'via Rastrelli ang. via '
#                                                 'Pecorari',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 19,
#                                      'rental_uris': {'android': 'bikemi://stations/2003',
#                                                      'ios': 'bikemi://stations/2003'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2003'},
#                            'free_bikes': 19,
#                            'id': '0e36b72fff9339531057727bb3a6cc51',
#                            'latitude': 45.4623491113649,
#                            'longitude': 9.191029719437132,
#                            'name': '83 - Rastrelli - Pecorari',
#                            'timestamp': '2025-02-06T20:49:44.944319Z'},
#                           {'empty_slots': 19,
#                            'extra': {'address': 'Taramelli RL',
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 12,
#                                      'rental_uris': {'android': 'bikemi://stations/2116',
#                                                      'ios': 'bikemi://stations/2116'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2116'},
#                            'free_bikes': 13,
#                            'id': '0e4de861aa3064167a016be965b71264',
#                            'latitude': 45.4907689453302,
#                            'longitude': 9.19381186366081,
#                            'name': '203 - Taramelli RL',
#                            'timestamp': '2025-02-06T20:49:44.919329Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': 'Via G. Pascoli ang. v.le '
#                                                 'Romagna',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 18,
#                                      'rental_uris': {'android': 'bikemi://stations/2127',
#                                                      'ios': 'bikemi://stations/2127'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2127'},
#                            'free_bikes': 20,
#                            'id': '0e88d775b022559f57f6ad922679a8cc',
#                            'latitude': 45.4764271,
#                            'longitude': 9.2242174,
#                            'name': '216 - Romagna - Pascoli',
#                            'timestamp': '2025-02-06T20:49:44.917912Z'},
#                           {'empty_slots': 12,
#                            'extra': {'address': "Medaglie D'Oro 2",
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 3,
#                                      'rental_uris': {'android': 'bikemi://stations/1991',
#                                                      'ios': 'bikemi://stations/1991'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 18,
#                                      'uid': '1991'},
#                            'free_bikes': 3,
#                            'id': '0edebdb4ad63dcbe4d3bd67950ce86bd',
#                            'latitude': 45.4518635297906,
#                            'longitude': 9.202967584133148,
#                            'name': "71 - Medaglie D'Oro 2",
#                            'timestamp': '2025-02-06T20:49:44.944566Z'},
#                           {'empty_slots': 3,
#                            'extra': {'address': 'Via Ressi ang. via Stefini',
#                                      'ebikes': 7,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 20,
#                                      'rental_uris': {'android': 'bikemi://stations/2217',
#                                                      'ios': 'bikemi://stations/2217'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2217'},
#                            'free_bikes': 27,
#                            'id': '105644b6bc039edbd7a294df73e54623',
#                            'latitude': 45.4968635864226,
#                            'longitude': 9.202852919697762,
#                            'name': '281 - Stefini - Ressi',
#                            'timestamp': '2025-02-06T20:49:44.916140Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': 'Via Primaticcio ang. via '
#                                                 'Corba',
#                                      'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 10,
#                                      'rental_uris': {'android': 'bikemi://stations/2241',
#                                                      'ios': 'bikemi://stations/2241'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2241'},
#                            'free_bikes': 13,
#                            'id': '106ff0aac5e6ff5e5549162694578b80',
#                            'latitude': 45.4530012694861,
#                            'longitude': 9.13344878650244,
#                            'name': '370 - Primaticcio - Corba',
#                            'timestamp': '2025-02-06T20:49:44.915776Z'},
#                           {'empty_slots': 18,
#                            'extra': {'address': 'Corso Indipendenza',
#                                      'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 14,
#                                      'rental_uris': {'android': 'bikemi://stations/2048',
#                                                      'ios': 'bikemi://stations/2048'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2048'},
#                            'free_bikes': 18,
#                            'id': '10e44c078d75c98d608567c40bdff7d3',
#                            'latitude': 45.4682780284177,
#                            'longitude': 9.21466737985611,
#                            'name': '128 - Indipendenza-Castel Morrone',
#                            'timestamp': '2025-02-06T20:49:44.919080Z'},
#                           {'empty_slots': 24,
#                            'extra': {'address': 'Montenero',
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 0,
#                                      'rental_uris': {'android': 'bikemi://stations/2055',
#                                                      'ios': 'bikemi://stations/2055'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 27,
#                                      'uid': '2055'},
#                            'free_bikes': 1,
#                            'id': '112d61694c09cc5c0bc980ad234bc6d5',
#                            'latitude': 45.4601362818685,
#                            'longitude': 9.207648038864136,
#                            'name': '136 - Montenero - Spartaco',
#                            'timestamp': '2025-02-06T20:49:44.944071Z'},
#                           {'empty_slots': 3,
#                            'extra': {'address': 'P.za Egeo ft. stazione',
#                                      'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 18,
#                                      'rental_uris': {'android': 'bikemi://stations/2213',
#                                                      'ios': 'bikemi://stations/2213'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2213'},
#                            'free_bikes': 21,
#                            'id': '115167846963f19eeb3071078bc8c4d7',
#                            'latitude': 45.5128561793357,
#                            'longitude': 9.213593155145645,
#                            'name': '324 - Staz. Greco - Pirelli - Cozzi',
#                            'timestamp': '2025-02-06T20:49:44.916227Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'Via Ciceri Visconti civ. 2',
#                                      'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 16,
#                                      'rental_uris': {'android': 'bikemi://stations/2245',
#                                                      'ios': 'bikemi://stations/2245'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2245'},
#                            'free_bikes': 20,
#                            'id': '1210382dc1660ededa71f78e6796ae80',
#                            'latitude': 45.4557114393844,
#                            'longitude': 9.22033353904083,
#                            'name': '357 - Ciceri Visconti - Martini',
#                            'timestamp': '2025-02-06T20:49:44.915714Z'},
#                           {'empty_slots': 20,
#                            'extra': {'address': "Piazza Dell'Umanitaria ang. "
#                                                 'via Fanti',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 3,
#                                      'rental_uris': {'android': 'bikemi://stations/2002',
#                                                      'ios': 'bikemi://stations/2002'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '2002'},
#                            'free_bikes': 3,
#                            'id': '124d28774fd44be23c48dcbfcee3a4e2',
#                            'latitude': 45.45807432212791,
#                            'longitude': 9.200611263513565,
#                            'name': "82 - Dell'Umanitaria",
#                            'timestamp': '2025-02-06T20:49:44.944225Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'Dateo',
#                                      'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 19,
#                                      'rental_uris': {'android': 'bikemi://stations/2053',
#                                                      'ios': 'bikemi://stations/2053'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2053'},
#                            'free_bikes': 22,
#                            'id': '1256a2cac8ca2d1f1097684d6d781d15',
#                            'latitude': 45.4684529652424,
#                            'longitude': 9.21672195196151,
#                            'name': '133 - Dateo',
#                            'timestamp': '2025-02-06T20:49:44.918502Z'},
#                           {'empty_slots': 6,
#                            'extra': {'address': 'Regina Margherita - fr civ 17',
#                                      'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 15,
#                                      'rental_uris': {'android': 'bikemi://stations/1943',
#                                                      'ios': 'bikemi://stations/1943'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '1943'},
#                            'free_bikes': 18,
#                            'id': '139e86f91c99517865698fd3b41fdc33',
#                            'latitude': 45.4582342395861,
#                            'longitude': 9.20530915260315,
#                            'name': '23 - Regina Margherita',
#                            'timestamp': '2025-02-06T20:49:44.945458Z'},
#                           {'empty_slots': 1,
#                            'extra': {'address': 'Naviglio G.Valenza',
#                                      'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 24,
#                                      'rental_uris': {'android': 'bikemi://stations/2077',
#                                                      'ios': 'bikemi://stations/2077'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 33,
#                                      'uid': '2077'},
#                            'free_bikes': 29,
#                            'id': '14115570217de71deac1966da1e1babf',
#                            'latitude': 45.4498182024788,
#                            'longitude': 9.16759729385375,
#                            'name': '158 - Naviglio G.Valenza',
#                            'timestamp': '2025-02-06T20:49:44.918000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'p.za del Rosario ang. via '
#                                                 'Bergognone',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 26,
#                                      'rental_uris': {'android': 'bikemi://stations/2082',
#                                                      'ios': 'bikemi://stations/2082'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2082'},
#                            'free_bikes': 26,
#                            'id': '14a663026e8e71c254aeab3f05ea3c72',
#                            'latitude': 45.4549332631759,
#                            'longitude': 9.16284441947937,
#                            'name': '163 - Rosario',
#                            'timestamp': '2025-02-06T20:49:44.918613Z'},
#                           {'empty_slots': 18,
#                            'extra': {'address': 'Piazza Santa Maria Beltrade - '
#                                                 'via Torino',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 10,
#                                      'rental_uris': {'android': 'bikemi://stations/1927',
#                                                      'ios': 'bikemi://stations/1927'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '1927'},
#                            'free_bikes': 10,
#                            'id': '14efa2234d1493b97599a0ddeaaa0291',
#                            'latitude': 45.4627662999143,
#                            'longitude': 9.18682873249054,
#                            'name': '7 - Santa Maria Beltrade',
#                            'timestamp': '2025-02-06T20:49:44.945690Z'},
#                           {'empty_slots': 14,
#                            'extra': {'address': 'largo Treves',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 6,
#                                      'rental_uris': {'android': 'bikemi://stations/1982',
#                                                      'ios': 'bikemi://stations/1982'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '1982'},
#                            'free_bikes': 8,
#                            'id': '158186a5229fecb7b4e9c0fbf44c730d',
#                            'latitude': 45.475071950022084,
#                            'longitude': 9.186791181564331,
#                            'name': '62 - Treves',
#                            'timestamp': '2025-02-06T20:49:44.944703Z'},
#                           {'empty_slots': 2,
#                            'extra': {'address': 'p.za Istria fr civ 12',
#                                      'ebikes': 5,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 19,
#                                      'rental_uris': {'android': 'bikemi://stations/2198',
#                                                      'ios': 'bikemi://stations/2198'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2198'},
#                            'free_bikes': 24,
#                            'id': '15a88e4745cb9a3161f50dfd9c78790c',
#                            'latitude': 45.5017751069887,
#                            'longitude': 9.198427945375443,
#                            'name': '310 - Istria M5 - F. Testi',
#                            'timestamp': '2025-02-06T20:49:44.916482Z'},
#                           {'empty_slots': 20,
#                            'extra': {'address': 'Pagano',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 8,
#                                      'rental_uris': {'android': 'bikemi://stations/2094',
#                                                      'ios': 'bikemi://stations/2094'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2094'},
#                            'free_bikes': 10,
#                            'id': '16acc8d37aae47452ef92f93518bf012',
#                            'latitude': 45.468255455884595,
#                            'longitude': 9.16047066450119,
#                            'name': "175 - Pagano - Guido D'Arezzo",
#                            'timestamp': '2025-02-06T20:49:44.944117Z'},
#                           {'empty_slots': 29,
#                            'extra': {'address': 'Piazzale Baracca',
#                                      'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 2,
#                                      'rental_uris': {'android': 'bikemi://stations/1999',
#                                                      'ios': 'bikemi://stations/1999'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '1999'},
#                            'free_bikes': 5,
#                            'id': '17e5c57bb36c6d95a05a62fbbfc7cdf3',
#                            'latitude': 45.466436456215305,
#                            'longitude': 9.165100157260895,
#                            'name': '79 - Baracca',
#                            'timestamp': '2025-02-06T20:49:44.945765Z'},
#                           {'empty_slots': 28,
#                            'extra': {'address': 'S.Gioachimo -Via G. Galiliei '
#                                                 'fr civ 14',
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 7,
#                                      'rental_uris': {'android': 'bikemi://stations/2027',
#                                                      'ios': 'bikemi://stations/2027'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 39,
#                                      'uid': '2027'},
#                            'free_bikes': 8,
#                            'id': '1b8c08b110edb6b1afb0b235c492cb4a',
#                            'latitude': 45.48086268896389,
#                            'longitude': 9.1970694065094,
#                            'name': '107 - S.Gioachimo',
#                            'timestamp': '2025-02-06T20:49:44.919239Z'},
#                           {'empty_slots': 0,
#                            'extra': {'address': 'Via Marussig civ 3',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 22,
#                                      'rental_uris': {'android': 'bikemi://stations/2189',
#                                                      'ios': 'bikemi://stations/2189'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2189'},
#                            'free_bikes': 24,
#                            'id': '1cd0075f8e2bbf679a45f8020d3c3bc0',
#                            'latitude': 45.4864153338653,
#                            'longitude': 9.165998804674018,
#                            'name': '239 - Marussig - Castelvetro',
#                            'timestamp': '2025-02-06T20:49:44.916603Z'},
#                           {'empty_slots': 10,
#                            'extra': {'address': 'Via San Tomaso',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 3,
#                                      'rental_uris': {'android': 'bikemi://stations/1994',
#                                                      'ios': 'bikemi://stations/1994'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 15,
#                                      'uid': '1994'},
#                            'free_bikes': 3,
#                            'id': '1e1e3c739bffb9b47cb5db4e28cbc2bd',
#                            'latitude': 45.467059098697085,
#                            'longitude': 9.184052646160126,
#                            'name': '74 - Dante - San Tomaso',
#                            'timestamp': '2025-02-06T20:49:44.945897Z'},
#                           {'empty_slots': 1,
#                            'extra': {'address': 'Corso Sempione alt. via '
#                                                 'Castelvetro',
#                                      'ebikes': 7,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 17,
#                                      'rental_uris': {'android': 'bikemi://stations/2219',
#                                                      'ios': 'bikemi://stations/2219'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2219'},
#                            'free_bikes': 24,
#                            'id': '1e9a191899ff5d77ae532a0264d49e28',
#                            'latitude': 45.48354588650152,
#                            'longitude': 9.162514410118888,
#                            'name': '220 - Sempione - Castelvetro',
#                            'timestamp': '2025-02-06T20:49:44.916111Z'},
#                           {'empty_slots': 8,
#                            'extra': {'address': 'P.za San Nazario in Brolo',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 13,
#                                      'rental_uris': {'android': 'bikemi://stations/1989',
#                                                      'ios': 'bikemi://stations/1989'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '1989'},
#                            'free_bikes': 13,
#                            'id': '1ed2efa003698f4ada72271a0e34c76a',
#                            'latitude': 45.45832642709111,
#                            'longitude': 9.192578047513962,
#                            'name': '69 - S. Nazaro in Brolo',
#                            'timestamp': '2025-02-06T20:49:44.944598Z'},
#                           {'empty_slots': 1,
#                            'extra': {'address': 'Sraffa',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 32,
#                                      'rental_uris': {'android': 'bikemi://stations/2069',
#                                                      'ios': 'bikemi://stations/2069'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2069'},
#                            'free_bikes': 32,
#                            'id': '1efdfbdffb9f696cdc1c8c1434dec1b5',
#                            'latitude': 45.44824887622469,
#                            'longitude': 9.186110571026802,
#                            'name': '150 - Sraffa',
#                            'timestamp': '2025-02-06T20:49:44.918164Z'},
#                           {'empty_slots': 4,
#                            'extra': {'address': 'Piazzale Velasquez',
#                                      'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 15,
#                                      'rental_uris': {'android': 'bikemi://stations/2257',
#                                                      'ios': 'bikemi://stations/2257'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 27,
#                                      'uid': '2257'},
#                            'free_bikes': 19,
#                            'id': '1f25c70005dbc652004fb3b4359b63a2',
#                            'latitude': 45.46746408237823,
#                            'longitude': 9.141293924937429,
#                            'name': '367 - Velasquez - Osoppo',
#                            'timestamp': '2025-02-06T20:49:44.915467Z'},
#                           {'empty_slots': 23,
#                            'extra': {'address': 'via Paleocapa 3',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 6,
#                                      'rental_uris': {'android': 'bikemi://stations/2004',
#                                                      'ios': 'bikemi://stations/2004'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2004'},
#                            'free_bikes': 6,
#                            'id': '210b291bca6a9464bc925fce6509e399',
#                            'latitude': 45.4690323220327,
#                            'longitude': 9.17622596025467,
#                            'name': '84 - Cadorna 2',
#                            'timestamp': '2025-02-06T20:49:44.944427Z'},
#                           {'empty_slots': 6,
#                            'extra': {'address': 'S. F. Romana',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 21,
#                                      'rental_uris': {'android': 'bikemi://stations/2030',
#                                                      'ios': 'bikemi://stations/2030'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 33,
#                                      'uid': '2030'},
#                            'free_bikes': 23,
#                            'id': '21a1c0a38525bd11b64b36976146cf4a',
#                            'latitude': 45.47641201642088,
#                            'longitude': 9.208573400974274,
#                            'name': '110 - S. F. Romana',
#                            'timestamp': '2025-02-06T20:49:44.918686Z'},
#                           {'empty_slots': 22,
#                            'extra': {'address': 'p.za Erculea - Via Rugabella',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 5,
#                                      'rental_uris': {'android': 'bikemi://stations/1940',
#                                                      'ios': 'bikemi://stations/1940'},
#                                      'renting': True,
# ...
#                            'free_bikes': 22,
#                            'id': 'f6d82cf7468041f766cccaa5c298dcab',
#                            'latitude': 45.4398393314734,
#                            'longitude': 9.22404184256379,
#                            'name': '340 - Corvetto - Polesine',
#                            'timestamp': '2025-02-06T20:49:44.916036Z'},
#                           {'empty_slots': 9,
#                            'extra': {'address': 'Via Isernia ang. P.za Santa '
#                                                 'Maria Nascente',
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 19,
#                                      'rental_uris': {'android': 'bikemi://stations/2188',
#                                                      'ios': 'bikemi://stations/2188'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2188'},
#                            'free_bikes': 20,
#                            'id': 'f707886fc51c31193a7091557fff15e8',
#                            'latitude': 45.48673641788378,
#                            'longitude': 9.13705235128873,
#                            'name': '229 - QT8 - Isernia',
#                            'timestamp': '2025-02-06T20:49:44.916620Z'},
#                           {'empty_slots': 12,
#                            'extra': {'address': 'via Bocconi " Università"',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 9,
#                                      'rental_uris': {'android': 'bikemi://stations/1941',
#                                                      'ios': 'bikemi://stations/1941'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '1941'},
#                            'free_bikes': 9,
#                            'id': 'f9c10afbe91f92aa191b280e48aaf1de',
#                            'latitude': 45.448721184042824,
#                            'longitude': 9.190414845943451,
#                            'name': '21 - Università Bocconi',
#                            'timestamp': '2025-02-06T20:49:44.945488Z'},
#                           {'empty_slots': 23,
#                            'extra': {'address': 'Restelli - Galvani RL 1',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 7,
#                                      'rental_uris': {'android': 'bikemi://stations/2026',
#                                                      'ios': 'bikemi://stations/2026'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2026'},
#                            'free_bikes': 9,
#                            'id': 'faa9d86716f52c85b61682dc1ceb6be1',
#                            'latitude': 45.4872733715353,
#                            'longitude': 9.19470772147178,
#                            'name': '106 - Restelli - Galvani RL 1',
#                            'timestamp': '2025-02-06T20:49:44.919311Z'},
#                           {'empty_slots': 3,
#                            'extra': {'address': 'Via Patellani',
#                                      'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 13,
#                                      'rental_uris': {'android': 'bikemi://stations/2009',
#                                                      'ios': 'bikemi://stations/2009'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '2009'},
#                            'free_bikes': 17,
#                            'id': 'fad809a5eed8099eaa1f277f65945b7c',
#                            'latitude': 45.45149584232627,
#                            'longitude': 9.194208036255873,
#                            'name': '89 - Patellani',
#                            'timestamp': '2025-02-06T20:49:44.945750Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'P.za Bernini',
#                                      'ebikes': 1,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 13,
#                                      'rental_uris': {'android': 'bikemi://stations/2122',
#                                                      'ios': 'bikemi://stations/2122'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 27,
#                                      'uid': '2122'},
#                            'free_bikes': 14,
#                            'id': 'fafb6cfbedbe9a470e6dc8ffcd5627ec',
#                            'latitude': 45.4788240556337,
#                            'longitude': 9.221670627593994,
#                            'name': '211 - Bernini',
#                            'timestamp': '2025-02-06T20:49:44.917971Z'},
#                           {'empty_slots': 13,
#                            'extra': {'address': 'P.za Angilberto II ang via '
#                                                 'Comacchio',
#                                      'ebikes': 2,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 20,
#                                      'rental_uris': {'android': 'bikemi://stations/2223',
#                                                      'ios': 'bikemi://stations/2223'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2223'},
#                            'free_bikes': 22,
#                            'id': 'fb3940bcdf3eff6373d07daf28b83f00',
#                            'latitude': 45.43697741283822,
#                            'longitude': 9.217861220551782,
#                            'name': '383 - Angilberto - Comacchio',
#                            'timestamp': '2025-02-06T20:49:44.916051Z'},
#                           {'empty_slots': 6,
#                            'extra': {'address': 'C.so Garibaldi ang. P.za XXV '
#                                                 'Aprile',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 15,
#                                      'rental_uris': {'android': 'bikemi://stations/1959',
#                                                      'ios': 'bikemi://stations/1959'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '1959'},
#                            'free_bikes': 15,
#                            'id': 'fb43af886011606871a8205b47f4dd34',
#                            'latitude': 45.4801818989517,
#                            'longitude': 9.186678528785706,
#                            'name': '39 - XXV Aprile',
#                            'timestamp': '2025-02-06T20:49:44.945055Z'},
#                           {'empty_slots': 14,
#                            'extra': {'address': 'Via Murat fr civ 38',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 11,
#                                      'rental_uris': {'android': 'bikemi://stations/2195',
#                                                      'ios': 'bikemi://stations/2195'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 30,
#                                      'uid': '2195'},
#                            'free_bikes': 11,
#                            'id': 'fb8bd481ceaf5fd2b2496e823ade5e04',
#                            'latitude': 45.4994949620154,
#                            'longitude': 9.190676361322403,
#                            'name': '280 - Murat - Villani - Milano Sport',
#                            'timestamp': '2025-02-06T20:49:44.916535Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'Via De Amicis civ. 23',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 8,
#                                      'rental_uris': {'android': 'bikemi://stations/2015',
#                                                      'ios': 'bikemi://stations/2015'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 21,
#                                      'uid': '2015'},
#                            'free_bikes': 8,
#                            'id': 'fb9b23df9a66db2553f1f7e4a4cdb694',
#                            'latitude': 45.458282214735,
#                            'longitude': 9.178663417696953,
#                            'name': '95 - De Amicis - Conca Del Naviglio',
#                            'timestamp': '2025-02-06T20:49:44.944256Z'},
#                           {'empty_slots': 7,
#                            'extra': {'address': 'Santissima Trinità',
#                                      'ebikes': 8,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 16,
#                                      'rental_uris': {'android': 'bikemi://stations/2102',
#                                                      'ios': 'bikemi://stations/2102'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2102'},
#                            'free_bikes': 24,
#                            'id': 'fbc7ef4f9c9df81d279986784b24ffb1',
#                            'latitude': 45.478021934753784,
#                            'longitude': 9.176444560289383,
#                            'name': '185 - Santissima Trinità',
#                            'timestamp': '2025-02-06T20:49:44.919397Z'},
#                           {'empty_slots': 24,
#                            'extra': {'address': 'P.za Diaz civ. 6',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 10,
#                                      'rental_uris': {'android': 'bikemi://stations/1984',
#                                                      'ios': 'bikemi://stations/1984'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 39,
#                                      'uid': '1984'},
#                            'free_bikes': 10,
#                            'id': 'fd4eec5611524f20f585152d8799a011',
#                            'latitude': 45.462064033133124,
#                            'longitude': 9.189676433752538,
#                            'name': '64 - Diaz',
#                            'timestamp': '2025-02-06T20:49:44.944672Z'},
#                           {'empty_slots': 6,
#                            'extra': {'address': 'Vercelli - Cherubini',
#                                      'ebikes': 3,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 22,
#                                      'rental_uris': {'android': 'bikemi://stations/2092',
#                                                      'ios': 'bikemi://stations/2092'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 36,
#                                      'uid': '2092'},
#                            'free_bikes': 25,
#                            'id': 'fdcff292ea4c425938ecf70b9309c740',
#                            'latitude': 45.4668465357227,
#                            'longitude': 9.15931463241577,
#                            'name': '173 - Vercelli - Cherubini',
#                            'timestamp': '2025-02-06T20:49:44.918566Z'},
#                           {'empty_slots': 12,
#                            'extra': {'address': 'San Marco - Castelfidardo',
#                                      'ebikes': 4,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 6,
#                                      'rental_uris': {'android': 'bikemi://stations/2018',
#                                                      'ios': 'bikemi://stations/2018'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 24,
#                                      'uid': '2018'},
#                            'free_bikes': 10,
#                            'id': 'ffae03ec709206aa7c247a76e2372196',
#                            'latitude': 45.4786933473828,
#                            'longitude': 9.189179688692093,
#                            'name': '98 - San Marco',
#                            'timestamp': '2025-02-06T20:49:44.944535Z'},
#                           {'empty_slots': 11,
#                            'extra': {'address': 'Porta Volta  civ. 5',
#                                      'ebikes': 0,
#                                      'has_ebikes': True,
#                                      'last_updated': 1738874971,
#                                      'normal_bikes': 22,
#                                      'rental_uris': {'android': 'bikemi://stations/2101',
#                                                      'ios': 'bikemi://stations/2101'},
#                                      'renting': True,
#                                      'returning': True,
#                                      'slots': 33,
#                                      'uid': '2101'},
#                            'free_bikes': 22,
#                            'id': 'ffed4450862bdb542355377ce018b724',
#                            'latitude': 45.4802336167138,
#                            'longitude': 9.182309210300446,
#                            'name': '184 - Porta Volta',
#                            'timestamp': '2025-02-06T20:49:44.944132Z'}]}}

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
# Locate the first station to simplify the view
network_json["network"]["stations"][0]
# Out:
# {'id': '00ac8507b9c64010d723191c2aa43c6c',
#  'name': '368 - Tolstoi - Lorenteggio',
#  'latitude': 45.453710246267775,
#  'longitude': 9.149430356583878,
#  'timestamp': '2025-02-06T20:49:44.915500Z',
#  'free_bikes': 20,
#  'empty_slots': 6,
#  'extra': {'uid': '2255',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1738874971,
#   'address': 'Via Tolstoi civ.53',
#   'slots': 30,
#   'normal_bikes': 14,
#   'ebikes': 6,
#   'has_ebikes': True,
#   'rental_uris': {'android': 'bikemi://stations/2255',
#    'ios': 'bikemi://stations/2255'}}}

# %%
import json

with open('milan.json', 'w') as f:
  json.dump(network_json, f)

# %%
network_json['network']['stations'][0]
# Out:
# {'id': '00ac8507b9c64010d723191c2aa43c6c',
#  'name': '368 - Tolstoi - Lorenteggio',
#  'latitude': 45.453710246267775,
#  'longitude': 9.149430356583878,
#  'timestamp': '2025-02-06T20:49:44.915500Z',
#  'free_bikes': 20,
#  'empty_slots': 6,
#  'extra': {'uid': '2255',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1738874971,
#   'address': 'Via Tolstoi civ.53',
#   'slots': 30,
#   'normal_bikes': 14,
#   'ebikes': 6,
#   'has_ebikes': True,
#   'rental_uris': {'android': 'bikemi://stations/2255',
#    'ios': 'bikemi://stations/2255'}}}

# %%
# creating lists of values from the milan json
names = [station['name'] for station in network_json['network']['stations']]
longitude = [station['longitude'] for station in network_json['network']['stations']]
latitude = [station['latitude'] for station in network_json['network']['stations']]
timestamp = [station['timestamp'] for station in network_json['network']['stations']]
free_bikes = [station['free_bikes'] for station in network_json['network']['stations']]
empty_slots = [station['empty_slots'] for station in network_json['network']['stations']]
total_slots = [station['extra']['slots'] for station in network_json['network']['stations']]

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
# Create a pd  DataFrame
import pandas as pd
df_milan = pd.DataFrame(
				{
			'name' : names,
            'longitude' : longitude,
            'latitude' : latitude,
            'timestamp': timestamp,
            'free_bikes': free_bikes,
            'empty_slots': empty_slots,
            'total_slots': total_slots
			}
		)
df_milan.head()
# Out:
#                             name  longitude   latitude  \
# 0    368 - Tolstoi - Lorenteggio   9.149430  45.453710
# 1                25 - Centrale 1   9.202572  45.485456
# 2      161 - Coni Zugna - Solari   9.168010  45.457079
# 3                   16 - Moscova   9.184560  45.477534
# 4  359 - Tertulliano - Caroncini   9.218048  45.449209
#
#                      timestamp  free_bikes  empty_slots  total_slots
# 0  2025-02-06T20:49:44.915500Z          20            6           30
# 1  2025-02-06T20:49:44.945428Z           8           13           24
# 2  2025-02-06T20:49:44.919206Z          25            0           36
# 3  2025-02-06T20:49:44.945565Z          14            7           24
# 4  2025-02-06T20:49:44.915729Z          11           15           27

# %%
# Create a csv file for the city of milan
df_milan.to_csv('milan.csv')
